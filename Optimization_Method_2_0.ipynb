# %% [markdown]
# <a href="https://colab.research.google.com/github/nafalza/OptimizationMethod/blob/main/Optimization_Method_2_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
df = pd.read_csv("/content/drive/MyDrive/File for Colab/data_clean.csv", low_memory=False)
df.head()
# Out:
#                           BAGIAN     PENYAKIT_KELUARGA KEHAMILAN KEBIASAAN  \
# 0           departemen mekanikal               jantung         -       NaN
# 1           departemen mekanikal  lain$    hepatitis $         -       NaN
# 2           departemen mekanikal                   NaN         -       NaN
# 3       bagian ammonia pusri iii                   NaN         -       NaN
# 4  program kemitraan usaha kecil                   NaN         -       NaN
#
#   OLAHRAGA ALERGI  TINGGI  BERAT   TENSI   NADI  ...  TRIGLISERIDA  \
# 0        +      -  1660.0  800.0  110/80  670.0  ...        1740.0
# 1        -      -  1600.0  570.0  110/80  760.0  ...         750.0
# 2        -      -  1550.0  520.0  120/70  830.0  ...         690.0
# 3        +      -  1590.0  570.0  110/60  580.0  ...        1170.0
# 4        +      -  1710.0  620.0  110/70  630.0  ...         590.0
#
#    HDL_KOLEST LDL_KOLEST  UREUM KREATININ ASAM_URAT_GINJAL GULA_DARAH_PUASA  \
# 0       420.0     1640.0  220.0     900.0           6100.0            860.0
# 1       390.0     1690.0  190.0      10.0           5300.0            930.0
# 2       670.0      940.0  200.0     500.0           2700.0            880.0
# 3       430.0     1340.0  190.0     900.0           5400.0           1250.0
# 4       540.0     1470.0  200.0    1100.0           5500.0           1070.0
#
#   GULA_DARAH_2JAMPP URINE_REDUKSI_PUASA URINE_REDUKSI_2JAMPP
# 0             870.0             negatif              negatif
# 1            1050.0             negatif              negatif
# 2             930.0             negatif              negatif
# 3            1970.0             negatif              negatif
# 4            1020.0             negatif              negatif
#
# [5 rows x 110 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10637 entries, 0 to 10636
# Columns: 110 entries, BAGIAN to URINE_REDUKSI_2JAMPP
# dtypes: float64(33), object(77)
# memory usage: 8.9+ MB

# %%
drop_cols = ["BAGIAN"]

# %%
df_clean = df.drop(columns =[c for c in drop_cols if c in df.columns])

# %%
output_path = "/content/drive/MyDrive/File for Colab/data_processed.csv"
df_clean.to_csv(output_path, index=False)
print(f"Processed data saved to {output_path}")
# Out:
# Processed data saved to /content/drive/MyDrive/File for Colab/data_processed.csv

# %%
df = pd.read_csv("/content/drive/MyDrive/File for Colab/data_processed.csv", low_memory=False)

# %%
df.head()
# Out:
#                           BAGIAN     PENYAKIT_KELUARGA KEHAMILAN KEBIASAAN  \
# 0           departemen mekanikal               jantung         -       NaN
# 1           departemen mekanikal  lain$    hepatitis $         -       NaN
# 2           departemen mekanikal                   NaN         -       NaN
# 3       bagian ammonia pusri iii                   NaN         -       NaN
# 4  program kemitraan usaha kecil                   NaN         -       NaN
#
#   OLAHRAGA ALERGI  TINGGI  BERAT   TENSI   NADI  ...  TRIGLISERIDA  \
# 0        +      -  1660.0  800.0  110/80  670.0  ...        1740.0
# 1        -      -  1600.0  570.0  110/80  760.0  ...         750.0
# 2        -      -  1550.0  520.0  120/70  830.0  ...         690.0
# 3        +      -  1590.0  570.0  110/60  580.0  ...        1170.0
# 4        +      -  1710.0  620.0  110/70  630.0  ...         590.0
#
#    HDL_KOLEST LDL_KOLEST  UREUM KREATININ ASAM_URAT_GINJAL GULA_DARAH_PUASA  \
# 0       420.0     1640.0  220.0     900.0           6100.0            860.0
# 1       390.0     1690.0  190.0      10.0           5300.0            930.0
# 2       670.0      940.0  200.0     500.0           2700.0            880.0
# 3       430.0     1340.0  190.0     900.0           5400.0           1250.0
# 4       540.0     1470.0  200.0    1100.0           5500.0           1070.0
#
#   GULA_DARAH_2JAMPP URINE_REDUKSI_PUASA URINE_REDUKSI_2JAMPP
# 0             870.0             negatif              negatif
# 1            1050.0             negatif              negatif
# 2             930.0             negatif              negatif
# 3            1970.0             negatif              negatif
# 4            1020.0             negatif              negatif
#
# [5 rows x 110 columns]

# %%
import pandas as pd
import numpy as np
import random
import math
import matplotlib.pyplot as plt

# 1. MANUAL K-PROTOTYPES IMPLEMENTATION
class ManualKPrototypes:
    """
    A manual implementation of K-Prototypes clustering.
    Combines K-Means (numerical) and K-Modes (categorical).
    """
    def __init__(self, n_clusters, gamma, max_iter=20, random_state=42):
        self.n_clusters = int(n_clusters)
        self.gamma = float(gamma)
        self.max_iter = max_iter
        self.random_state = random_state
        self.centroids_num_ = None
        self.centroids_cat_ = None
        self.cost_ = None
        self.labels_ = None

    def fit_predict(self, X_num, X_cat):
        np.random.seed(self.random_state)
        n_samples, n_num_feats = X_num.shape
        _, n_cat_feats = X_cat.shape

        # --- Initialization ---
        random_indices = np.random.choice(n_samples, self.n_clusters, replace=False)
        self.centroids_num_ = X_num[random_indices].copy()
        self.centroids_cat_ = X_cat[random_indices].copy()

        labels = np.zeros(n_samples)

        for iteration in range(self.max_iter):
            # Calculate Numerical Distance (Euclidean Squared)
            # Broadcasting: (N, 1, D) - (1, K, D) -> (N, K, D)
            # Sum over dimensions -> (N, K)
            dist_num = np.sum((X_num[:, np.newaxis, :] - self.centroids_num_[np.newaxis, :, :]) ** 2, axis=2)

            # Calculate Categorical Distance (Hamming / Matching)
            # 1 if different, 0 if same. Sum over dimensions.
            dist_cat = np.sum(X_cat[:, np.newaxis, :] != self.centroids_cat_[np.newaxis, :, :], axis=2)

            # Total Cost = Num_Dist + Gamma * Cat_Dist
            total_dist = dist_num + (self.gamma * dist_cat)

            # Assign points to the nearest centroid
            new_labels = np.argmin(total_dist, axis=1)

            if np.array_equal(labels, new_labels):
                break
            labels = new_labels

            # --- 2. Update Step ---
            for k in range(self.n_clusters):
                mask = (labels == k)
                if np.sum(mask) == 0: continue # Handle empty cluster

                # Update Numerical Centroids (Mean)
                self.centroids_num_[k] = np.mean(X_num[mask], axis=0)

                # Update Categorical Centroids (Mode)
                cluster_cat_data = X_cat[mask]
                for col_idx in range(n_cat_feats):
                    # Get unique values and their counts
                    values, counts = np.unique(cluster_cat_data[:, col_idx], return_counts=True)
                    # The new centroid value is the one with maximum count
                    self.centroids_cat_[k, col_idx] = values[np.argmax(counts)]

        # Final Cost Calculation
        dist_num = np.sum((X_num[:, np.newaxis, :] - self.centroids_num_[np.newaxis, :, :]) ** 2, axis=2)
        dist_cat = np.sum(X_cat[:, np.newaxis, :] != self.centroids_cat_[np.newaxis, :, :], axis=2)
        min_dists = np.min(dist_num + (self.gamma * dist_cat), axis=1)
        self.cost_ = np.sum(min_dists)
        self.labels_ = labels

        return labels, self.cost_

# 2. DATA LOADING & MANUAL PREPROCESSING
print("Loading data")
csv_path = "/content/drive/MyDrive/File for Colab/data_processed.csv"
df = pd.read_csv(csv_path)

# Identify columns
cat_cols = df.select_dtypes(include=["object"]).columns.tolist()
num_cols = df.select_dtypes(exclude=["object"]).columns.tolist()

# Manual Missing Value Imputation
for col in num_cols:
    df[col] = pd.to_numeric(df[col], errors="coerce")
    median_val = df[col].median()
    df[col] = df[col].fillna(median_val)

# Categorical: Fill with "Unknown"
for col in cat_cols:
    df[col] = df[col].astype(str).replace("nan", "Unknown")

# Manual Standard Scaling
# Formula: z = (x - mean) / std
X_num_raw = df[num_cols].values
means = np.mean(X_num_raw, axis=0)
stds = np.std(X_num_raw, axis=0)
stds[stds == 0] = 1  # Prevent division by zero
X_num = (X_num_raw - means) / stds

X_cat = df[cat_cols].values

print(f"Data Ready. Shape: {df.shape}")
print(f"Numerical features: {X_num.shape[1]}, Categorical features: {X_cat.shape[1]}")

# 3. GENETIC ALGORITHM (OPTIMIZATION)

# GA Parameters
POPULATION_SIZE = 10
N_GENERATIONS = 5   # Kept small for demonstration, increase to 10-20 for real run
MUTATION_RATE = 0.3
K_MIN, K_MAX = 2, 6
GAMMA_MIN, GAMMA_MAX = 0.1, 5.0
SAMPLE_SIZE = 1000  # Use subset for speed during optimization

# Cache to store results of (k, gamma) to avoid re-computing
fitness_cache = {}

def evaluate_fitness(individual, X_num, X_cat):
    """
    Runs Manual K-Prototypes and returns the cost.
    individual = [k, gamma]
    """
    k, gamma = individual
    k = int(round(k))

    # Bounds check
    k = max(K_MIN, min(K_MAX, k))
    gamma = max(GAMMA_MIN, min(GAMMA_MAX, gamma))

    # Check cache
    key = (k, round(gamma, 3))
    if key in fitness_cache:
        return fitness_cache[key]

    # Use a random sample for speed
    if X_num.shape[0] > SAMPLE_SIZE:
        idx = np.random.choice(X_num.shape[0], SAMPLE_SIZE, replace=False)
        X_num_sub = X_num[idx]
        X_cat_sub = X_cat[idx]
    else:
        X_num_sub, X_cat_sub = X_num, X_cat

    # Run Manual Clustering
    try:
        kp = ManualKPrototypes(n_clusters=k, gamma=gamma, max_iter=10)
        _, cost = kp.fit_predict(X_num_sub, X_cat_sub)
    except Exception as e:
        cost = float('inf')

    fitness_cache[key] = cost
    return cost

def create_population(size):
    pop = []
    for _ in range(size):
        k = random.randint(K_MIN, K_MAX)
        gamma = random.uniform(GAMMA_MIN, GAMMA_MAX)
        pop.append([k, gamma])
    return pop

def mutate(individual):
    k, gamma = individual
    # Mutate k
    if random.random() < MUTATION_RATE:
        k += random.choice([-1, 1])
        k = max(K_MIN, min(K_MAX, k))
    # Mutate gamma
    if random.random() < MUTATION_RATE:
        gamma += random.uniform(-0.5, 0.5)
        gamma = max(GAMMA_MIN, min(GAMMA_MAX, gamma))
    return [k, gamma]

def crossover(p1, p2):
    # Swap gamma between parents
    c1 = [p1[0], p2[1]]
    c2 = [p2[0], p1[1]]
    return c1, c2

# --- Run GA ---
print("\nStarting Genetic Algorithm Optimization...")
population = create_population(POPULATION_SIZE)
best_costs_history = []
best_global_ind = None
best_global_cost = float('inf')

for gen in range(N_GENERATIONS):
    # Evaluate
    scored_pop = []
    for ind in population:
        cost = evaluate_fitness(ind, X_num, X_cat)
        scored_pop.append((ind, cost))

        if cost < best_global_cost:
            best_global_cost = cost
            best_global_ind = ind[:]

    # Sort by cost (lowest is best)
    scored_pop.sort(key=lambda x: x[1])
    best_gen_cost = scored_pop[0][1]
    best_costs_history.append(best_gen_cost)

    print(f"Gen {gen+1}: Best Cost = {best_gen_cost:.2f} (k={scored_pop[0][0][0]}, gamma={scored_pop[0][0][1]:.2f})")

    # Selection & Next Gen
    new_pop = [scored_pop[0][0]] # Elitism: keep best

    while len(new_pop) < POPULATION_SIZE:
        # Tournament Selection (pick 2 random, take best)
        candidates = random.sample(scored_pop, 2)
        parent1 = min(candidates, key=lambda x: x[1])[0]
        candidates = random.sample(scored_pop, 2)
        parent2 = min(candidates, key=lambda x: x[1])[0]

        child1, child2 = crossover(parent1, parent2)
        new_pop.append(mutate(child1))
        if len(new_pop) < POPULATION_SIZE:
            new_pop.append(mutate(child2))

    population = new_pop

print("\nOptimization Finished!")
print(f"Best Parameters: k={best_global_ind[0]}, gamma={best_global_ind[1]:.3f}")
print(f"Best Cost: {best_global_cost:.2f}")

# 4. PLOTTING
plt.figure(figsize=(8, 5))
plt.plot(range(1, N_GENERATIONS+1), best_costs_history, marker='o', linestyle='-')
plt.title('GA Optimization Progress (Manual Implementation)')
plt.xlabel('Generation')
plt.ylabel('Cost (Objective Function)')
plt.grid(True)
plt.show()

# 5. FINAL CLUSTERING & SCATTER PLOT
if best_global_ind is not None:
    best_k = int(round(best_global_ind[0]))
    best_gamma = float(best_global_ind[1])
    print(f"\n--- Running Final Clustering on Full Data ---")
    print(f"Parameters: k={best_k}, gamma={best_gamma:.3f}")

    # Run final clustering on full dataset
    kp_final = ManualKPrototypes(n_clusters=best_k, gamma=best_gamma, max_iter=50, random_state=42)
    labels_final, cost_final = kp_final.fit_predict(X_num, X_cat)
    print(f"Final Cost: {cost_final:.2f}")

    # Cluster sizes
    unique_labels, counts = np.unique(labels_final, return_counts=True)
    print(f"\nCluster Distribution:")
    for lbl, cnt in zip(unique_labels, counts):
        print(f"  Cluster {int(lbl)}: {int(cnt)} points ({100*cnt/len(labels_final):.1f}%)")

    # ========== DETAILED CLUSTER ANALYSIS ==========
    print("\n" + "="*80)
    print("DETAILED CLUSTER CHARACTERISTICS & INTERPRETATION")
    print("="*80)

    cluster_names = {}

    for k in range(best_k):
        mask = (labels_final == k)
        cluster_size = np.sum(mask)

        print(f"\n{'='*80}")
        print(f"🔹 CLUSTER {int(k)} - {int(cluster_size)} members ({100*cluster_size/len(labels_final):.1f}%)")
        print(f"{'='*80}")

        # Numerical Features Summary
        print(f"\n📊 Numerical Features (Mean ± Std):")
        print(f"-" * 80)
        key_features = []
        for col_idx, col_name in enumerate(num_cols):
            cluster_vals = X_num_raw[mask, col_idx]
            mean_val = np.mean(cluster_vals)
            std_val = np.std(cluster_vals)
            global_mean = np.mean(X_num_raw[:, col_idx])
            diff_pct = 100 * (mean_val - global_mean) / (global_mean + 1e-6) if global_mean != 0 else 0
            marker = " ⬆️" if diff_pct > 15 else " ⬇️" if diff_pct < -15 else ""
            print(f"  {col_name:25s}: {mean_val:10.2f} ± {std_val:7.2f}  (Global: {global_mean:.2f}, Diff: {diff_pct:+.1f}%){marker}")

            # Capture significant differences for naming
            if abs(diff_pct) > 20:
                key_features.append(f"{col_name}:{mean_val:.0f}")

        # Categorical Features Summary
        print(f"\n🏷️  Categorical Features (Mode & Distribution):")
        print(f"-" * 80)
        for col_idx, col_name in enumerate(cat_cols):
            cluster_cat = X_cat[mask, col_idx]
            unique_vals, counts_cat = np.unique(cluster_cat, return_counts=True)

            # Find mode
            mode_idx = np.argmax(counts_cat)
            mode_val = unique_vals[mode_idx]
            mode_count = counts_cat[mode_idx]
            mode_pct = 100 * mode_count / len(cluster_cat)

            print(f"  {col_name:25s}: '{mode_val}' ({int(mode_count)}/{int(len(cluster_cat))} = {mode_pct:.1f}%)")

            # Capture for naming if it's dominant
            if mode_pct > 60:
                key_features.append(f"{col_name}={mode_val[:10]}")

            # Show top 3 values
            sorted_idx = np.argsort(counts_cat)[::-1]
            if len(sorted_idx) > 1:
                print(f"    {'Top values:':25s}", end="")
                for i, idx in enumerate(sorted_idx[:3]):
                    if i > 0:
                        print(f"{'':27s}", end="")
                    print(f"'{unique_vals[idx]}': {counts_cat[idx]} ({100*counts_cat[idx]/len(cluster_cat):.1f}%)")

        # Generate cluster interpretation
        interpretation = " | ".join(key_features[:3]) if key_features else "General cluster"
        cluster_names[k] = interpretation
        print(f"\n💡 CLUSTER INTERPRETATION: {interpretation}")

        # Centroid values
        print(f"\n Cluster Centroid (Normalized Numerical):")
        print(f"-" * 80)
        print(f"  {str(kp_final.centroids_num_[k])}")
        print(f"\n Cluster Centroid (Categorical):")
        print(f"  {str(kp_final.centroids_cat_[k])}")

    # 2D Projection using SVD
    print("\nComputing 2D projection via SVD...")
    X_mean = X_num.mean(axis=0)
    X_centered = X_num - X_mean
    U, S, Vt = np.linalg.svd(X_centered, full_matrices=False)
    X_proj = (U * S)[:, :2]  # Project to first 2 principal components

    # Project centroids
    components = Vt.T[:, :2]
    centroids_proj = (kp_final.centroids_num_ - X_mean).dot(components)

    # Create scatter plot
    fig, ax = plt.subplots(figsize=(10, 7))

    # Define colors for clusters
    colors = plt.cm.tab10(np.linspace(0, 1, best_k))

    # Plot points for each cluster
    for k in range(best_k):
        mask = (labels_final == k)
        ax.scatter(X_proj[mask, 0], X_proj[mask, 1],
                  c=[colors[k]], s=50, alpha=0.6,
                  label=f'Cluster {k} (n={int(np.sum(mask))})',
                  edgecolors='black', linewidth=0.5)

    # Plot centroids
    ax.scatter(centroids_proj[:, 0], centroids_proj[:, 1],
              c='red', s=300, marker='X',
              label='Centroids', edgecolors='darkred', linewidth=2, zorder=5)

    ax.set_xlabel(f'PC1', fontsize=12)
    ax.set_ylabel(f'PC2', fontsize=12)
    ax.set_title(f'K-Prototypes Clustering Result (k={best_k}, γ={best_gamma:.3f})', fontsize=14, fontweight='bold')
    ax.legend(loc='best', fontsize=10)
    ax.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

    print("\n✓ Overall scatter plot displayed!")

    # ========== INDIVIDUAL SCATTER PLOTS FOR EACH CLUSTER ==========
    print("\nGenerating individual scatter plots for each cluster...")

    for k in range(best_k):
        mask = (labels_final == k)
        cluster_size = np.sum(mask)

        fig, ax = plt.subplots(figsize=(9, 6))

        # Plot only this cluster's points
        ax.scatter(X_proj[mask, 0], X_proj[mask, 1],
                  c=[colors[k]], s=80, alpha=0.7,
                  label=f'Cluster {k} ({int(cluster_size)} points)',
                  edgecolors='black', linewidth=0.5)

        # Plot this cluster's centroid
        ax.scatter(centroids_proj[k, 0], centroids_proj[k, 1],
                  c='red', s=400, marker='X',
                  label='Centroid', edgecolors='darkred', linewidth=2, zorder=5)

        ax.set_xlabel(f'PC1', fontsize=12)
        ax.set_ylabel(f'PC2', fontsize=12)
        ax.set_title(f'Cluster {k}: {cluster_names[k]}\n({int(cluster_size)} members, {100*cluster_size/len(labels_final):.1f}%)',
                    fontsize=12, fontweight='bold')
        ax.legend(loc='best', fontsize=10)
        ax.grid(True, alpha=0.3)
        plt.tight_layout()
        plt.show()

    print("\n✓ All individual cluster scatter plots displayed!")

    # ========== COMPREHENSIVE CLUSTER INTERPRETATION SUMMARY ==========
    print("\n" + "="*80)
    print("📋 CLUSTER INTERPRETATION SUMMARY & BUSINESS INSIGHTS")
    print("="*80)

    for k in range(best_k):
        mask = (labels_final == k)
        cluster_size = np.sum(mask)

        print(f"\n{'='*80}")
        print(f"CLUSTER {int(k)}: {cluster_names[k]}")
        print(f"{'='*80}")
        print(f"Size: {int(cluster_size)} members ({100*cluster_size/len(labels_final):.1f}% of total)")

        # Build detailed interpretation
        interpretation_parts = []

        # Analyze numerical features
        num_interpretation = []
        for col_idx, col_name in enumerate(num_cols):
            cluster_vals = X_num_raw[mask, col_idx]
            mean_val = np.mean(cluster_vals)
            global_mean = np.mean(X_num_raw[:, col_idx])
            global_std = np.std(X_num_raw[:, col_idx])
            z_score = (mean_val - global_mean) / (global_std + 1e-6)

            if abs(z_score) > 1.5:
                direction = "significantly higher" if z_score > 0 else "significantly lower"
                num_interpretation.append(f"  • {col_name}: {direction} ({mean_val:.2f} vs {global_mean:.2f})")

        if num_interpretation:
            print(f"\n🔢 Numerical Characteristics:")
            for item in num_interpretation:
                print(item)

        # Analyze categorical features
        cat_interpretation = []
        for col_idx, col_name in enumerate(cat_cols):
            cluster_cat = X_cat[mask, col_idx]
            unique_vals, counts_cat = np.unique(cluster_cat, return_counts=True)
            mode_idx = np.argmax(counts_cat)
            mode_val = unique_vals[mode_idx]
            mode_pct = 100 * counts_cat[mode_idx] / len(cluster_cat)

            # Only mention if dominant (>60%)
            if mode_pct > 60:
                cat_interpretation.append(f"  • {col_name}: Predominantly '{mode_val}' ({mode_pct:.1f}%)")

        if cat_interpretation:
            print(f"\n🏷️  Categorical Characteristics:")
            for item in cat_interpretation:
                print(item)

        # Generate business-friendly description
        print(f"\n Business Interpretation:")
        if len(num_interpretation) > 0 or len(cat_interpretation) > 0:
            description_elements = []

            # Add categorical descriptors first
            for col_idx, col_name in enumerate(cat_cols):
                cluster_cat = X_cat[mask, col_idx]
                unique_vals, counts_cat = np.unique(cluster_cat, return_counts=True)
                mode_idx = np.argmax(counts_cat)
                mode_val = unique_vals[mode_idx]
                description_elements.append(f"{col_name}='{mode_val}'")

            # Add significant numerical descriptors
            for col_idx, col_name in enumerate(num_cols[:3]):  # Limit to first 3
                cluster_vals = X_num_raw[mask, col_idx]
                mean_val = np.mean(cluster_vals)
                description_elements.append(f"{col_name}≈{mean_val:.1f}")

            full_description = " | ".join(description_elements[:4])
            print(f"  {full_description}")
        else:
            print(f"  Mixed group with no dominant characteristics")

        # Risk or opportunity assessment
        print(f"\n Key Insights:")
        if 'KELUHAN' in cat_cols:
            col_idx = cat_cols.index('KELUHAN')
            cluster_cat = X_cat[mask, col_idx]
            has_complaint = (cluster_cat != 'nan').sum()
            print(f"  • Complaint Rate: {100*has_complaint/len(cluster_cat):.1f}%")

        # Health metrics if available
        health_metrics = ['TENSI', 'NADI', 'SUHU', 'BERAT', 'TINGGI']
        relevant_metrics = [m for m in health_metrics if m in num_cols]
        if relevant_metrics:
            print(f"  • Health Metrics Present: {', '.join(relevant_metrics[:3])}")

    print("\n" + "="*80)
    print("ANALYSIS COMPLETE")
    print("="*80)
    print(f"\nTotal Clusters: {best_k}")
    print(f"Optimization Parameters: k={best_k}, gamma={best_gamma:.3f}")
    print(f"Final Cost: {cost_final:.2f}")

else:
    print("No best parameters found. Cannot run final clustering.")
# Out:
# Loading data
# /tmp/ipython-input-30406500.py:87: DtypeWarning: Columns (62) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path)
# Data Ready. Shape: (10637, 109)
# Numerical features: 33, Categorical features: 76
#
# Starting Genetic Algorithm Optimization...
# Gen 1: Best Cost = 28936.93 (k=3, gamma=0.35)
# Gen 2: Best Cost = 25684.80 (k=6, gamma=0.31)
# Gen 3: Best Cost = 24387.38 (k=6, gamma=0.19)
# Gen 4: Best Cost = 23983.19 (k=6, gamma=0.15)
# Gen 5: Best Cost = 23387.57 (k=6, gamma=0.10)
#
# Optimization Finished!
# Best Parameters: k=6, gamma=0.100
# Best Cost: 23387.57
# --- Running Final Clustering on Full Data ---
# Parameters: k=6, gamma=0.100
# Final Cost: 304629.08
#
# Cluster Distribution:
#   Cluster 0: 2223 points (20.9%)
#   Cluster 1: 9 points (0.1%)
#   Cluster 2: 249 points (2.3%)
#   Cluster 3: 2774 points (26.1%)
#   Cluster 4: 868 points (8.2%)
#   Cluster 5: 4514 points (42.4%)
#
# ================================================================================
# DETAILED CLUSTER CHARACTERISTICS & INTERPRETATION
# ================================================================================
#
# ================================================================================
# 🔹 CLUSTER 0 - 2223 members (20.9%)
# ================================================================================
#
# 📊 Numerical Features (Mean ± Std):
# --------------------------------------------------------------------------------
#   TINGGI                   :    1682.36 ±   61.93  (Global: 1653.67, Diff: +1.7%)
#   BERAT                    :     752.40 ± 2098.57  (Global: 732.17, Diff: +2.8%)
#   NADI                     :     703.07 ±   96.09  (Global: 735.44, Diff: -4.4%)
#   PERNAPASAN               :     210.07 ±  429.57  (Global: 211.78, Diff: -0.8%)
#   SUHU                     :    3266.82 ± 9822.79  (Global: 3397.95, Diff: -3.9%)
#   HB                       :   14587.63 ± 2274.93  (Global: 12847.87, Diff: +13.5%)
#   LEUKOSIT                 :    6254.69 ± 2884.04  (Global: 6480.02, Diff: -3.5%)
#   LED                      :      98.09 ±   94.85  (Global: 170.01, Diff: -42.3%) ⬇️
#   EOSINOPIL                :      18.48 ±   14.50  (Global: 17.48, Diff: +5.7%)
#   BASOPIL                  :       1.59 ±    3.74  (Global: 1.52, Diff: +4.4%)
#   STAF                     :      10.26 ±    3.28  (Global: 10.79, Diff: -5.0%)
#   SEGMENT                  :     577.62 ±   70.63  (Global: 583.26, Diff: -1.0%)
#   LYMPOSIT                 :     350.64 ±   70.74  (Global: 345.79, Diff: +1.4%)
#   MONOSIT                  :      56.82 ±   22.41  (Global: 56.18, Diff: +1.1%)
#   ERITROSIT                :     240.06 ±    2.95  (Global: 239.97, Diff: +0.0%)
#   TROMBOSIT                :    2558.27 ±  542.19  (Global: 2750.93, Diff: -7.0%)
#   HEMATOKRIT               :     299.00 ±    0.00  (Global: 299.00, Diff: +0.0%)
#   BILIRUBIN_TOTAL          :     897.10 ±  289.30  (Global: 582.52, Diff: +54.0%) ⬆️
#   BILIRUBIN_DIRECT         :     317.45 ±  109.40  (Global: 214.99, Diff: +47.7%) ⬆️
#   BILIRUBIN_INDIRECT       :     582.05 ±  210.60  (Global: 369.91, Diff: +57.3%) ⬆️
#   ALKALINE_PHOSPAT         :     737.86 ±  212.51  (Global: 752.97, Diff: -2.0%)
#   SGPT                     :     265.26 ±  186.99  (Global: 292.08, Diff: -9.2%)
#   SGOT                     :     217.33 ±   97.04  (Global: 223.40, Diff: -2.7%)
#   GAMMA_GT                 :     312.54 ±  249.49  (Global: 370.85, Diff: -15.7%) ⬇️
#   KOLEST_TOTAL             :    1789.95 ±  312.87  (Global: 1971.84, Diff: -9.2%)
#   TRIGLISERIDA             :    1080.02 ±  536.12  (Global: 1323.61, Diff: -18.4%) ⬇️
#   HDL_KOLEST               :     498.29 ±  109.01  (Global: 498.68, Diff: -0.1%)
#   LDL_KOLEST               :    1244.29 ±  300.48  (Global: 1390.46, Diff: -10.5%)
#   UREUM                    :     226.02 ±   56.11  (Global: 218.16, Diff: +3.6%)
#   KREATININ                :     672.69 ±  451.28  (Global: 676.19, Diff: -0.5%)
#   ASAM_URAT_GINJAL         :    5547.65 ± 2257.15  (Global: 5398.13, Diff: +2.8%)
#   GULA_DARAH_PUASA         :     907.00 ±   97.17  (Global: 943.02, Diff: -3.8%)
#   GULA_DARAH_2JAMPP        :     941.99 ±  161.08  (Global: 1003.05, Diff: -6.1%)
#
# 🏷️  Categorical Features (Mode & Distribution):
# --------------------------------------------------------------------------------
#   PENYAKIT_KELUARGA        : 'Unknown' (1280/2223 = 57.6%)
#     Top values:              'Unknown': 1280 (57.6%)
#                            'darah tinggi': 366 (16.5%)
#                            'kencing manis': 126 (5.7%)
#   KEHAMILAN                : '-' (2172/2223 = 97.7%)
#     Top values:              '-': 2172 (97.7%)
#                            'Unknown': 51 (2.3%)
#   KEBIASAAN                : 'Unknown' (1419/2223 = 63.8%)
#     Top values:              'Unknown': 1419 (63.8%)
#                            'merokok': 182 (8.2%)
#                            'lain$  r/ minum obat : becefort $': 10 (0.4%)
#   OLAHRAGA                 : '+' (1523/2223 = 68.5%)
#     Top values:              '+': 1523 (68.5%)
#                            '-': 700 (31.5%)
#   ALERGI                   : '-' (2186/2223 = 98.3%)
#     Top values:              '-': 2186 (98.3%)
#                            '+': 37 (1.7%)
#   TENSI                    : '120/70' (492/2223 = 22.1%)
#     Top values:              '120/70': 492 (22.1%)
#                            '110/70': 421 (18.9%)
#                            '120/80': 404 (18.2%)
#   KULIT_RAMBUT             : 'normal' (2222/2223 = 100.0%)
#     Top values:              'normal': 2222 (100.0%)
#                            'Unknown': 1 (0.0%)
#   VISUS_MATA               : 'od :  e os :  e' (2223/2223 = 100.0%)
#   PENYAKIT_MATA            : 'normal' (2222/2223 = 100.0%)
#     Top values:              'normal': 2222 (100.0%)
#                            'hordeolum pre orbita dextra': 1 (0.0%)
#   CONJUNGTIVA              : 'normal' (2188/2223 = 98.4%)
#     Top values:              'normal': 2188 (98.4%)
#                            'anemis': 35 (1.6%)
#   SCLERA                   : 'normal' (2221/2223 = 99.9%)
#     Top values:              'normal': 2221 (99.9%)
#                            'icteric': 2 (0.1%)
#   KELAINAN_MATA_LAIN       : 'Unknown' (2214/2223 = 99.6%)
#     Top values:              'Unknown': 2214 (99.6%)
#                            'ptergium grade i mata kiri': 2 (0.1%)
#                            'pterygium gr i os (+)': 1 (0.0%)
#   TELINGA                  : 'normal' (1338/2223 = 60.2%)
#     Top values:              'normal': 1338 (60.2%)
#                            'tidak periksa': 472 (21.2%)
#                            'tidak diperiksa': 307 (13.8%)
#   MEMBRAN_TYMPANI          : 'normal' (1334/2223 = 60.0%)
#     Top values:              'normal': 1334 (60.0%)
#                            'tidak periksa': 474 (21.3%)
#                            'tidak diperiksa': 307 (13.8%)
#   REFLEK_CAHAYA            : 'normal' (1337/2223 = 60.1%)
#     Top values:              'normal': 1337 (60.1%)
#                            'tidak periksa': 474 (21.3%)
#                            'tidak diperiksa': 306 (13.8%)
#   SERUMEN_PLUG             : 'normal' (1167/2223 = 52.5%)
#     Top values:              'normal': 1167 (52.5%)
#                            'tidak periksa': 473 (21.3%)
#                            'tidak diperiksa': 307 (13.8%)
#   HIDUNG                   : 'normal' (1340/2223 = 60.3%)
#     Top values:              'normal': 1340 (60.3%)
#                            'tidak periksa': 474 (21.3%)
#                            'tidak diperiksa': 307 (13.8%)
#   SEPTUM_DEVIASI           : 'normal' (1335/2223 = 60.1%)
#     Top values:              'normal': 1335 (60.1%)
#                            'tidak periksa': 474 (21.3%)
#                            'tidak diperiksa': 307 (13.8%)
#   CONCHA                   : 'normal' (1305/2223 = 58.7%)
#     Top values:              'normal': 1305 (58.7%)
#                            'tidak periksa': 474 (21.3%)
#                            'tidak diperiksa': 307 (13.8%)
#   POLYP                    : 'normal' (1337/2223 = 60.1%)
#     Top values:              'normal': 1337 (60.1%)
#                            'tidak periksa': 474 (21.3%)
#                            'tidak diperiksa': 306 (13.8%)
#   KERONGKONGAN             : 'normal' (1339/2223 = 60.2%)
#     Top values:              'normal': 1339 (60.2%)
#                            'tidak periksa': 474 (21.3%)
#                            'tidak diperiksa': 307 (13.8%)
#   TONSIL                   : 'normal' (1265/2223 = 56.9%)
#     Top values:              'normal': 1265 (56.9%)
#                            'tidak periksa': 474 (21.3%)
#                            'tidak diperiksa': 307 (13.8%)
#   FARING                   : 'normal' (1306/2223 = 58.7%)
#     Top values:              'normal': 1306 (58.7%)
#                            'tidak periksa': 473 (21.3%)
#                            'tidak diperiksa': 307 (13.8%)
#   AUDIOGRAM                : 'tidak diperiksa' (1033/2223 = 46.5%)
#     Top values:              'tidak diperiksa': 1033 (46.5%)
#                            'tidak periksa': 514 (23.1%)
#                            'normal': 447 (20.1%)
#   HERNIA                   : 'normal' (2220/2223 = 99.9%)
#     Top values:              'normal': 2220 (99.9%)
#                            'ada': 2 (0.1%)
#                            'scrotalis dextra': 1 (0.0%)
#   HAEMORROID               : 'normal' (2128/2223 = 95.7%)
#     Top values:              'normal': 2128 (95.7%)
#                            'ada': 74 (3.3%)
#                            'ada grade 1': 4 (0.2%)
#   SPINCER_ANI              : 'normal' (2223/2223 = 100.0%)
#   EPIDIDYMIS_TESTIS_PROSTAT: 'normal' (2054/2223 = 92.4%)
#     Top values:              'normal': 2054 (92.4%)
#                            'Unknown': 168 (7.6%)
#                            'susp orchitis testis dextra': 1 (0.0%)
#   VARICOCELE_HYDROCELE     : 'normal' (2055/2223 = 92.4%)
#     Top values:              'normal': 2055 (92.4%)
#                            'Unknown': 168 (7.6%)
#   FLOUR_ALBUS              : 'Unknown' (2055/2223 = 92.4%)
#     Top values:              'Unknown': 2055 (92.4%)
#                            'normal': 165 (7.4%)
#                            'ada': 3 (0.1%)
#   PAPS_SMEAR               : 'Unknown' (2094/2223 = 94.2%)
#     Top values:              'Unknown': 2094 (94.2%)
#                            'normal': 128 (5.8%)
#                            'tidak periksa': 1 (0.0%)
#   LEHER                    : 'normal' (2220/2223 = 99.9%)
#     Top values:              'normal': 2220 (99.9%)
#                            'tampak benjolan ukuran 2x1x1/2 sewarna kulit': 1 (0.0%)
#                            'pembesaran kgb': 1 (0.0%)
#   JVP                      : 'normal' (2223/2223 = 100.0%)
#   STRUMA                   : 'normal' (2223/2223 = 100.0%)
#   GIGI                     : 'Unknown' (1264/2223 = 56.9%)
#     Top values:              'Unknown': 1264 (56.9%)
#                            '-': 334 (15.0%)
#                            'scalling': 147 (6.6%)
#   MULUT                    : 'tidak diperiksa' (984/2223 = 44.3%)
#     Top values:              'tidak diperiksa': 984 (44.3%)
#                            'normal': 561 (25.2%)
#                            'tidak periksa': 559 (25.1%)
#   GUSI                     : 'tidak diperiksa' (982/2223 = 44.2%)
#     Top values:              'tidak diperiksa': 982 (44.2%)
#                            'normal': 561 (25.2%)
#                            'tidak periksa': 559 (25.1%)
#   BATAS_JANTUNG            : 'normal' (2222/2223 = 100.0%)
#     Top values:              'normal': 2222 (100.0%)
#                            'tidak periksa': 1 (0.0%)
#   IRAMA_JANTUNG            : 'normal' (2217/2223 = 99.7%)
#     Top values:              'normal': 2217 (99.7%)
#                            'iregular': 2 (0.1%)
#                            'ireguler': 2 (0.1%)
#   SUARA_JANTUNG_MURMUR     : 'normal' (2221/2223 = 99.9%)
#     Top values:              'normal': 2221 (99.9%)
#                            'wheezing dikedua lapang paru': 1 (0.0%)
#                            'tidak periksa': 1 (0.0%)
#   ECG                      : 'normal' (2059/2223 = 92.6%)
#     Top values:              'normal': 2059 (92.6%)
#                            'sinus bradikardia': 45 (2.0%)
#                            'sinus bradikardi': 14 (0.6%)
#   TREADMILL_TEST           : '(t)-' (1804/2223 = 81.2%)
#     Top values:              '(t)-': 1804 (81.2%)
#                            '(t)': 223 (10.0%)
#                            '(t)tidak melakukan': 28 (1.3%)
#   PERKUSI                  : 'normal' (2223/2223 = 100.0%)
#   AUSKULTASI               : 'normal' (2222/2223 = 100.0%)
#     Top values:              'normal': 2222 (100.0%)
#                            'wheezing minimal lapang paru kiri': 1 (0.0%)
#   THORAX_PHOTO             : 'normal' (1372/2223 = 61.7%)
#     Top values:              'normal': 1372 (61.7%)
#                            'tidak periksa': 452 (20.3%)
#                            'tidak diperiksa': 265 (11.9%)
#   AUTOSPIROMETRI           : 'tidak diperiksa' (1033/2223 = 46.5%)
#     Top values:              'tidak diperiksa': 1033 (46.5%)
#                            'tidak periksa': 515 (23.2%)
#                            'tidak di periksa': 101 (4.5%)
#   TREMOR                   : 'normal' (2203/2223 = 99.1%)
#     Top values:              'normal': 2203 (99.1%)
#                            'ada': 11 (0.5%)
#                            'halus tangan kiri': 1 (0.0%)
#   SEMBAB                   : 'normal' (2222/2223 = 100.0%)
#     Top values:              'normal': 2222 (100.0%)
#                            'ada': 1 (0.0%)
#   PARALYSE                 : 'normal' (2222/2223 = 100.0%)
#     Top values:              'normal': 2222 (100.0%)
#                            'Unknown': 1 (0.0%)
#   PUPIL                    : 'normal' (2223/2223 = 100.0%)
#   PATELA                   : 'normal' (2223/2223 = 100.0%)
#   ARCHILES                 : 'normal' (2223/2223 = 100.0%)
#   DINDING_PERUT            : 'normal' (2223/2223 = 100.0%)
#   PERUT                    : 'normal' (2195/2223 = 98.7%)
#     Top values:              'normal': 2195 (98.7%)
#                            'nyeri tekan epigastrium': 8 (0.4%)
#                            'nyeri tekan': 6 (0.3%)
#   HATI                     : 'normal' (2223/2223 = 100.0%)
#   LIMPA                    : 'normal' (2222/2223 = 100.0%)
#     Top values:              'normal': 2222 (100.0%)
#                            'teraba': 1 (0.0%)
#   GINJAL_ABDIMEN           : 'normal' (2223/2223 = 100.0%)
#   USG_ABDOMEN              : 'Unknown' (2223/2223 = 100.0%)
#   GINJAL_TLG_BELAKANG      : 'normal' (2223/2223 = 100.0%)
#   PROTEIN_ALBUMIN          : 'negatif' (2214/2223 = 99.6%)
#     Top values:              'negatif': 2214 (99.6%)
#                            'positif 1': 7 (0.3%)
#                            'positif': 2 (0.1%)
#   REDUKSI                  : 'negatif' (2222/2223 = 100.0%)
#     Top values:              'negatif': 2222 (100.0%)
#                            'positif 1': 1 (0.0%)
#   UROBILINOGEN             : 'negatif' (2223/2223 = 100.0%)
#   BILIRUBIN                : 'negatif' (2223/2223 = 100.0%)
#   ERITROSIT_RBC            : '0-1' (1969/2223 = 88.6%)
#     Top values:              '0-1': 1969 (88.6%)
#                            '1-2': 171 (7.7%)
#                            '0-2': 31 (1.4%)
#   LEKOSIT_WBC              : '0-1' (1476/2223 = 66.4%)
#     Top values:              '0-1': 1476 (66.4%)
#                            '1-2': 438 (19.7%)
#                            '0-2': 128 (5.8%)
#   SEL_EPITEL               : '0-1' (1478/2223 = 66.5%)
#     Top values:              '0-1': 1478 (66.5%)
#                            '1-2': 354 (15.9%)
#                            '0-2': 144 (6.5%)
#   ASAM_URAT_URIN           : 'negatif' (2223/2223 = 100.0%)
#   AMORF                    : 'negatif' (2215/2223 = 99.6%)
#     Top values:              'negatif': 2215 (99.6%)
#                            'positif': 7 (0.3%)
#                            'positif 3': 1 (0.0%)
#   TRIPLE_PHOSP             : 'negatif' (2223/2223 = 100.0%)
#   CA_OX                    : 'negatif' (2211/2223 = 99.5%)
#     Top values:              'negatif': 2211 (99.5%)
#                            'positif': 12 (0.5%)
#   GRANULER                 : 'negatif' (2223/2223 = 100.0%)
#   HYALINE                  : 'negatif' (2222/2223 = 100.0%)
#     Top values:              'negatif': 2222 (100.0%)
#                            'positif': 1 (0.0%)
#   BAKTERI                  : 'negatif' (2193/2223 = 98.7%)
#     Top values:              'negatif': 2193 (98.7%)
#                            'positif': 30 (1.3%)
#   URIN_LAIN2               : 'Unknown' (2222/2223 = 100.0%)
#     Top values:              'Unknown': 2222 (100.0%)
#                            'jamur (+)': 1 (0.0%)
#   URINE_REDUKSI_PUASA      : 'negatif' (2222/2223 = 100.0%)
#     Top values:              'negatif': 2222 (100.0%)
#                            'positif 1': 1 (0.0%)
#   URINE_REDUKSI_2JAMPP     : 'negatif' (2204/2223 = 99.1%)
#     Top values:              'negatif': 2204 (99.1%)
#                            'tab': 6 (0.3%)
#                            'positif 1': 6 (0.3%)
#
# 💡 CLUSTER INTERPRETATION: LED:98 | BILIRUBIN_TOTAL:897 | BILIRUBIN_DIRECT:317
#
#  Cluster Centroid (Normalized Numerical):
# --------------------------------------------------------------------------------
#   [ 3.86472240e-01  1.40519626e-02 -3.12087625e-02 -3.26566656e-03
#  -1.30823403e-02  3.88458377e-01 -8.17950413e-02 -4.67906733e-01
#   7.38126920e-02  1.65549188e-02 -2.91588233e-02 -6.44904308e-02
#   5.82985391e-02  3.34669935e-02  2.10261011e-02 -3.25723462e-01
#   5.07509346e-04  1.24294875e+00  1.17223964e+00  1.18218491e+00
#  -5.57549070e-02 -1.13169912e-01 -4.83046191e-02 -1.49570418e-01
#  -4.85182644e-01 -2.72293848e-01 -3.02260577e-03 -4.16913189e-01
#   1.25666766e-01 -8.16579957e-03  6.52727372e-02 -1.52887474e-01
#  -1.78322370e-01]
#
#  Cluster Centroid (Categorical):
#   ['Unknown' '-' 'Unknown' '+' '-' '120/70' 'normal' 'od :  e os :  e'
#  'normal' 'normal' 'normal' 'Unknown' 'normal' 'normal' 'normal' 'normal'
#  'normal' 'normal' 'normal' 'normal' 'normal' 'normal' 'normal'
#  'tidak diperiksa' 'normal' 'normal' 'normal' 'normal' 'normal' 'Unknown'
#  'Unknown' 'normal' 'normal' 'normal' 'Unknown' 'tidak diperiksa'
#  'tidak diperiksa' 'normal' 'normal' 'normal' 'normal' '(t)-' 'normal'
#  'normal' 'normal' 'tidak diperiksa' 'normal' 'normal' 'normal' 'normal'
#  'normal' 'normal' 'normal' 'normal' 'normal' 'normal' 'normal' 'Unknown'
#  'normal' 'negatif' 'negatif' 'negatif' 'negatif' '0-1' '0-1' '0-1'
#  'negatif' 'negatif' 'negatif' 'negatif' 'negatif' 'negatif' 'negatif'
#  'Unknown' 'negatif' 'negatif']
#
# ================================================================================
# 🔹 CLUSTER 1 - 9 members (0.1%)
# ================================================================================
#
# 📊 Numerical Features (Mean ± Std):
# --------------------------------------------------------------------------------
#   TINGGI                   :    1683.33 ±   63.25  (Global: 1653.67, Diff: +1.8%)
#   BERAT                    :     764.44 ±  119.82  (Global: 732.17, Diff: +4.4%)
#   NADI                     :     691.11 ±   86.98  (Global: 735.44, Diff: -6.0%)
#   PERNAPASAN               :     200.00 ±    0.00  (Global: 211.78, Diff: -5.6%)
#   SUHU                     :    8391.11 ± 15024.83  (Global: 3397.95, Diff: +146.9%) ⬆️
#   HB                       :   14188.89 ±  849.11  (Global: 12847.87, Diff: +10.4%)
#   LEUKOSIT                 :    6930.00 ± 3000.94  (Global: 6480.02, Diff: +6.9%)
#   LED                      :     170.00 ±   73.79  (Global: 170.01, Diff: -0.0%)
#   EOSINOPIL                :      11.11 ±    7.37  (Global: 17.48, Diff: -36.5%) ⬇️
#   BASOPIL                  :      58.89 ±   20.25  (Global: 1.52, Diff: +3771.5%) ⬆️
#   STAF                     :      10.00 ±    0.00  (Global: 10.79, Diff: -7.4%)
#   SEGMENT                  :     585.56 ±   15.71  (Global: 583.26, Diff: +0.4%)
#   LYMPOSIT                 :     371.11 ±   67.24  (Global: 345.79, Diff: +7.3%)
#   MONOSIT                  :      66.67 ±   14.14  (Global: 56.18, Diff: +18.7%) ⬆️
#   ERITROSIT                :     240.00 ±    0.00  (Global: 239.97, Diff: +0.0%)
#   TROMBOSIT                :    2652.22 ±  243.21  (Global: 2750.93, Diff: -3.6%)
#   HEMATOKRIT               :     299.00 ±    0.00  (Global: 299.00, Diff: +0.0%)
#   BILIRUBIN_TOTAL          :     528.89 ±  229.22  (Global: 582.52, Diff: -9.2%)
#   BILIRUBIN_DIRECT         :     230.00 ±   70.08  (Global: 214.99, Diff: +7.0%)
#   BILIRUBIN_INDIRECT       :     408.89 ±  129.14  (Global: 369.91, Diff: +10.5%)
#   ALKALINE_PHOSPAT         :     758.89 ±  176.60  (Global: 752.97, Diff: +0.8%)
#   SGPT                     :     566.67 ±  494.77  (Global: 292.08, Diff: +94.0%) ⬆️
#   SGOT                     :     310.00 ±  187.50  (Global: 223.40, Diff: +38.8%) ⬆️
#   GAMMA_GT                 :     740.00 ±  543.36  (Global: 370.85, Diff: +99.5%) ⬆️
#   KOLEST_TOTAL             :    2250.00 ±  636.94  (Global: 1971.84, Diff: +14.1%)
#   TRIGLISERIDA             :    1252.22 ±  585.81  (Global: 1323.61, Diff: -5.4%)
#   HDL_KOLEST               :     565.56 ±   91.91  (Global: 498.68, Diff: +13.4%)
#   LDL_KOLEST               :    1583.33 ±  558.03  (Global: 1390.46, Diff: +13.9%)
#   UREUM                    :     237.78 ±   63.21  (Global: 218.16, Diff: +9.0%)
#   KREATININ                :     790.00 ±  289.29  (Global: 676.19, Diff: +16.8%) ⬆️
#   ASAM_URAT_GINJAL         :    5507.78 ± 2268.00  (Global: 5398.13, Diff: +2.0%)
#   GULA_DARAH_PUASA         :     902.22 ±  160.68  (Global: 943.02, Diff: -4.3%)
#   GULA_DARAH_2JAMPP        :    1140.00 ±  339.18  (Global: 1003.05, Diff: +13.7%)
#
# 🏷️  Categorical Features (Mode & Distribution):
# --------------------------------------------------------------------------------
#   PENYAKIT_KELUARGA        : 'Unknown' (7/9 = 77.8%)
#     Top values:              'Unknown': 7 (77.8%)
#                            'darah tinggi, stroke, jantung': 1 (11.1%)
#                            'darah tinggi': 1 (11.1%)
#   KEHAMILAN                : '-' (9/9 = 100.0%)
#   KEBIASAAN                : 'Unknown' (8/9 = 88.9%)
#     Top values:              'Unknown': 8 (88.9%)
#                            'lain$  riwayat konsumsi obat cdr dan vitamin d3 (semalam)$': 1 (11.1%)
#   OLAHRAGA                 : '-' (8/9 = 88.9%)
#     Top values:              '-': 8 (88.9%)
#                            '+': 1 (11.1%)
#   ALERGI                   : '-' (9/9 = 100.0%)
#   TENSI                    : '110/70' (3/9 = 33.3%)
#     Top values:              '120/70': 3 (33.3%)
#                            '110/70': 3 (33.3%)
#                            '110/80': 2 (22.2%)
#   KULIT_RAMBUT             : 'normal' (9/9 = 100.0%)
#   VISUS_MATA               : 'od :  e os :  e' (9/9 = 100.0%)
#   PENYAKIT_MATA            : 'normal' (9/9 = 100.0%)
#   CONJUNGTIVA              : 'normal' (9/9 = 100.0%)
#   SCLERA                   : 'normal' (9/9 = 100.0%)
#   KELAINAN_MATA_LAIN       : 'Unknown' (9/9 = 100.0%)
#   TELINGA                  : 'tidak di periksa' (5/9 = 55.6%)
#     Top values:              'tidak di periksa': 5 (55.6%)
#                            'tidak periksa': 3 (33.3%)
#                            'tidak diperiksa': 1 (11.1%)
#   MEMBRAN_TYMPANI          : 'tidak di periksa' (5/9 = 55.6%)
#     Top values:              'tidak di periksa': 5 (55.6%)
#                            'tidak periksa': 3 (33.3%)
#                            'tidak diperiksa': 1 (11.1%)
#   REFLEK_CAHAYA            : 'tidak di periksa' (5/9 = 55.6%)
#     Top values:              'tidak di periksa': 5 (55.6%)
#                            'tidak periksa': 3 (33.3%)
#                            'tidak diperiksa': 1 (11.1%)
#   SERUMEN_PLUG             : 'tidak di periksa' (5/9 = 55.6%)
#     Top values:              'tidak di periksa': 5 (55.6%)
#                            'tidak periksa': 3 (33.3%)
#                            'tidak diperiksa': 1 (11.1%)
#   HIDUNG                   : 'tidak di periksa' (5/9 = 55.6%)
#     Top values:              'tidak di periksa': 5 (55.6%)
#                            'tidak periksa': 3 (33.3%)
#                            'tidak diperiksa': 1 (11.1%)
#   SEPTUM_DEVIASI           : 'tidak di periksa' (5/9 = 55.6%)
#     Top values:              'tidak di periksa': 5 (55.6%)
#                            'tidak periksa': 3 (33.3%)
#                            'tidak diperiksa': 1 (11.1%)
#   CONCHA                   : 'tidak di periksa' (5/9 = 55.6%)
#     Top values:              'tidak di periksa': 5 (55.6%)
#                            'tidak periksa': 3 (33.3%)
#                            'tidak diperiksa': 1 (11.1%)
#   POLYP                    : 'tidak di periksa' (5/9 = 55.6%)
#     Top values:              'tidak di periksa': 5 (55.6%)
#                            'tidak periksa': 3 (33.3%)
#                            'tidak diperiksa': 1 (11.1%)
#   KERONGKONGAN             : 'tidak di periksa' (5/9 = 55.6%)
#     Top values:              'tidak di periksa': 5 (55.6%)
#                            'tidak periksa': 3 (33.3%)
#                            'tidak diperiksa': 1 (11.1%)
#   TONSIL                   : 'tidak di periksa' (5/9 = 55.6%)
#     Top values:              'tidak di periksa': 5 (55.6%)
#                            'tidak periksa': 3 (33.3%)
#                            'tidak diperiksa': 1 (11.1%)
#   FARING                   : 'tidak di periksa' (5/9 = 55.6%)
#     Top values:              'tidak di periksa': 5 (55.6%)
#                            'tidak periksa': 3 (33.3%)
#                            'tidak diperiksa': 1 (11.1%)
#   AUDIOGRAM                : 'tidak di periksa' (5/9 = 55.6%)
#     Top values:              'tidak di periksa': 5 (55.6%)
#                            'tidak periksa': 3 (33.3%)
#                            'tidak diperiksa': 1 (11.1%)
#   HERNIA                   : 'normal' (9/9 = 100.0%)
#   HAEMORROID               : 'normal' (9/9 = 100.0%)
#   SPINCER_ANI              : 'normal' (9/9 = 100.0%)
#   EPIDIDYMIS_TESTIS_PROSTAT: 'normal' (8/9 = 88.9%)
#     Top values:              'normal': 8 (88.9%)
#                            'Unknown': 1 (11.1%)
#   VARICOCELE_HYDROCELE     : 'normal' (8/9 = 88.9%)
#     Top values:              'normal': 8 (88.9%)
#                            'Unknown': 1 (11.1%)
#   FLOUR_ALBUS              : 'Unknown' (8/9 = 88.9%)
#     Top values:              'Unknown': 8 (88.9%)
#                            'normal': 1 (11.1%)
#   PAPS_SMEAR               : 'Unknown' (8/9 = 88.9%)
#     Top values:              'Unknown': 8 (88.9%)
#                            'normal': 1 (11.1%)
#   LEHER                    : 'normal' (9/9 = 100.0%)
#   JVP                      : 'normal' (9/9 = 100.0%)
#   STRUMA                   : 'normal' (9/9 = 100.0%)
#   GIGI                     : '-' (8/9 = 88.9%)
#     Top values:              '-': 8 (88.9%)
#                            'Unknown': 1 (11.1%)
#   MULUT                    : 'tidak di periksa' (5/9 = 55.6%)
#     Top values:              'tidak di periksa': 5 (55.6%)
#                            'tidak periksa': 3 (33.3%)
#                            'tidak diperiksa': 1 (11.1%)
#   GUSI                     : 'tidak di periksa' (5/9 = 55.6%)
#     Top values:              'tidak di periksa': 5 (55.6%)
#                            'tidak periksa': 3 (33.3%)
#                            'tidak diperiksa': 1 (11.1%)
#   BATAS_JANTUNG            : 'normal' (9/9 = 100.0%)
#   IRAMA_JANTUNG            : 'normal' (9/9 = 100.0%)
#   SUARA_JANTUNG_MURMUR     : 'normal' (9/9 = 100.0%)
#   ECG                      : 'normal' (9/9 = 100.0%)
#   TREADMILL_TEST           : '(t)-' (7/9 = 77.8%)
#     Top values:              '(t)-': 7 (77.8%)
#                            '(t)': 2 (22.2%)
#   PERKUSI                  : 'normal' (9/9 = 100.0%)
#   AUSKULTASI               : 'normal' (9/9 = 100.0%)
#   THORAX_PHOTO             : 'tidak di periksa' (5/9 = 55.6%)
#     Top values:              'tidak di periksa': 5 (55.6%)
#                            'tidak periksa': 3 (33.3%)
#                            'tidak diperiksa': 1 (11.1%)
#   AUTOSPIROMETRI           : 'tidak di periksa' (5/9 = 55.6%)
#     Top values:              'tidak di periksa': 5 (55.6%)
#                            'tidak periksa': 3 (33.3%)
#                            'tidak diperiksa': 1 (11.1%)
#   TREMOR                   : 'normal' (9/9 = 100.0%)
#   SEMBAB                   : 'normal' (9/9 = 100.0%)
#   PARALYSE                 : 'normal' (9/9 = 100.0%)
#   PUPIL                    : 'normal' (9/9 = 100.0%)
#   PATELA                   : 'normal' (9/9 = 100.0%)
#   ARCHILES                 : 'normal' (9/9 = 100.0%)
#   DINDING_PERUT            : 'normal' (9/9 = 100.0%)
#   PERUT                    : 'normal' (9/9 = 100.0%)
#   HATI                     : 'normal' (9/9 = 100.0%)
#   LIMPA                    : 'normal' (9/9 = 100.0%)
#   GINJAL_ABDIMEN           : 'normal' (9/9 = 100.0%)
#   USG_ABDOMEN              : 'Unknown' (9/9 = 100.0%)
#   GINJAL_TLG_BELAKANG      : 'normal' (9/9 = 100.0%)
#   PROTEIN_ALBUMIN          : 'negatif' (9/9 = 100.0%)
#   REDUKSI                  : 'negatif' (9/9 = 100.0%)
#   UROBILINOGEN             : 'negatif' (9/9 = 100.0%)
#   BILIRUBIN                : 'negatif' (9/9 = 100.0%)
#   ERITROSIT_RBC            : '0-1' (7/9 = 77.8%)
#     Top values:              '0-1': 7 (77.8%)
#                            '1-2': 2 (22.2%)
#   LEKOSIT_WBC              : '1-2' (5/9 = 55.6%)
#     Top values:              '1-2': 5 (55.6%)
#                            '0-1': 4 (44.4%)
#   SEL_EPITEL               : '0-1' (6/9 = 66.7%)
#     Top values:              '0-1': 6 (66.7%)
#                            '1-2': 2 (22.2%)
#                            '3-4': 1 (11.1%)
#   ASAM_URAT_URIN           : 'negatif' (9/9 = 100.0%)
#   AMORF                    : 'negatif' (9/9 = 100.0%)
#   TRIPLE_PHOSP             : 'negatif' (9/9 = 100.0%)
#   CA_OX                    : 'negatif' (9/9 = 100.0%)
#   GRANULER                 : 'negatif' (9/9 = 100.0%)
#   HYALINE                  : 'negatif' (9/9 = 100.0%)
#   BAKTERI                  : 'negatif' (9/9 = 100.0%)
#   URIN_LAIN2               : 'Unknown' (9/9 = 100.0%)
#   URINE_REDUKSI_PUASA      : 'negatif' (9/9 = 100.0%)
#   URINE_REDUKSI_2JAMPP     : 'negatif' (8/9 = 88.9%)
#     Top values:              'negatif': 8 (88.9%)
#                            'positif': 1 (11.1%)
#
# 💡 CLUSTER INTERPRETATION: SUHU:8391 | EOSINOPIL:11 | BASOPIL:59
#
#  Cluster Centroid (Normalized Numerical):
# --------------------------------------------------------------------------------
#   [ 3.99623093e-01  2.24226041e-02 -4.27364133e-02 -2.24361527e-02
#   4.98158463e-01  2.99426308e-01  1.63343846e-01 -3.67015277e-05
#  -4.70523452e-01  1.42091301e+01 -4.30805614e-02  2.63054444e-02
#   3.04405326e-01  5.55940518e-01  7.04295814e-03 -1.66884600e-01
#   5.07509346e-04 -2.11893906e-01  1.71674964e-01  2.17237786e-01
#   2.18249364e-02  1.15838971e+00  6.89331021e-01  9.46770395e-01
#   7.41937853e-01 -7.98022261e-02  5.06983436e-01  5.50144394e-01
#   3.13745585e-01  2.65555185e-01  4.78665279e-02 -1.73184904e-01
#   3.99946368e-01]
#
#  Cluster Centroid (Categorical):
#   ['Unknown' '-' 'Unknown' '-' '-' '110/70' 'normal' 'od :  e os :  e'
#  'normal' 'normal' 'normal' 'Unknown' 'tidak di periksa'
#  'tidak di periksa' 'tidak di periksa' 'tidak di periksa'
#  'tidak di periksa' 'tidak di periksa' 'tidak di periksa'
#  'tidak di periksa' 'tidak di periksa' 'tidak di periksa'
#  'tidak di periksa' 'tidak di periksa' 'normal' 'normal' 'normal' 'normal'
#  'normal' 'Unknown' 'Unknown' 'normal' 'normal' 'normal' '-'
#  'tidak di periksa' 'tidak di periksa' 'normal' 'normal' 'normal' 'normal'
#  '(t)-' 'normal' 'normal' 'tidak di periksa' 'tidak di periksa' 'normal'
#  'normal' 'normal' 'normal' 'normal' 'normal' 'normal' 'normal' 'normal'
#  'normal' 'normal' 'Unknown' 'normal' 'negatif' 'negatif' 'negatif'
#  'negatif' '0-1' '1-2' '0-1' 'negatif' 'negatif' 'negatif' 'negatif'
#  'negatif' 'negatif' 'negatif' 'Unknown' 'negatif' 'negatif']
#
# ================================================================================
# 🔹 CLUSTER 2 - 249 members (2.3%)
# ================================================================================
#
# 📊 Numerical Features (Mean ± Std):
# --------------------------------------------------------------------------------
#   TINGGI                   :    1656.95 ±   67.62  (Global: 1653.67, Diff: +0.2%)
#   BERAT                    :     766.51 ±  139.07  (Global: 732.17, Diff: +4.7%)
#   NADI                     :     792.41 ±  104.85  (Global: 735.44, Diff: +7.7%)
#   PERNAPASAN               :     200.00 ±    0.00  (Global: 211.78, Diff: -5.6%)
#   SUHU                     :    4713.41 ± 11762.29  (Global: 3397.95, Diff: +38.7%) ⬆️
#   HB                       :   13538.88 ± 4298.87  (Global: 12847.87, Diff: +5.4%)
#   LEUKOSIT                 :    7130.40 ± 3163.21  (Global: 6480.02, Diff: +10.0%)
#   LED                      :     205.46 ±  159.94  (Global: 170.01, Diff: +20.9%) ⬆️
#   EOSINOPIL                :      16.14 ±   11.07  (Global: 17.48, Diff: -7.7%)
#   BASOPIL                  :       1.53 ±    3.60  (Global: 1.52, Diff: +0.3%)
#   STAF                     :      10.36 ±    4.14  (Global: 10.79, Diff: -4.0%)
#   SEGMENT                  :     607.75 ±   82.16  (Global: 583.26, Diff: +4.2%)
#   LYMPOSIT                 :     316.47 ±   75.48  (Global: 345.79, Diff: -8.5%)
#   MONOSIT                  :      53.21 ±   14.26  (Global: 56.18, Diff: -5.3%)
#   ERITROSIT                :     240.00 ±    0.00  (Global: 239.97, Diff: +0.0%)
#   TROMBOSIT                :    2621.89 ±  619.32  (Global: 2750.93, Diff: -4.7%)
#   HEMATOKRIT               :     299.00 ±    0.00  (Global: 299.00, Diff: +0.0%)
#   BILIRUBIN_TOTAL          :     594.62 ±  228.99  (Global: 582.52, Diff: +2.1%)
#   BILIRUBIN_DIRECT         :     219.80 ±   79.15  (Global: 214.99, Diff: +2.2%)
#   BILIRUBIN_INDIRECT       :     370.76 ±  166.84  (Global: 369.91, Diff: +0.2%)
#   ALKALINE_PHOSPAT         :    1053.90 ± 1089.84  (Global: 752.97, Diff: +40.0%) ⬆️
#   SGPT                     :     443.82 ±  366.47  (Global: 292.08, Diff: +51.9%) ⬆️
#   SGOT                     :     287.55 ±  253.20  (Global: 223.40, Diff: +28.7%) ⬆️
#   GAMMA_GT                 :     892.29 ± 1251.78  (Global: 370.85, Diff: +140.6%) ⬆️
#   KOLEST_TOTAL             :    2261.77 ±  455.55  (Global: 1971.84, Diff: +14.7%)
#   TRIGLISERIDA             :    2062.01 ± 1308.21  (Global: 1323.61, Diff: +55.8%) ⬆️
#   HDL_KOLEST               :     457.19 ±   98.05  (Global: 498.68, Diff: -8.3%)
#   LDL_KOLEST               :    1613.69 ±  427.95  (Global: 1390.46, Diff: +16.1%) ⬆️
#   UREUM                    :     236.83 ±   79.31  (Global: 218.16, Diff: +8.6%)
#   KREATININ                :     690.92 ±  365.63  (Global: 676.19, Diff: +2.2%)
#   ASAM_URAT_GINJAL         :    4684.90 ± 2093.73  (Global: 5398.13, Diff: -13.2%)
#   GULA_DARAH_PUASA         :    2158.47 ±  613.03  (Global: 943.02, Diff: +128.9%) ⬆️
#   GULA_DARAH_2JAMPP        :    2760.76 ±  743.67  (Global: 1003.05, Diff: +175.2%) ⬆️
#
# 🏷️  Categorical Features (Mode & Distribution):
# --------------------------------------------------------------------------------
#   PENYAKIT_KELUARGA        : 'Unknown' (113/249 = 45.4%)
#     Top values:              'Unknown': 113 (45.4%)
#                            'kencing manis': 57 (22.9%)
#                            'darah tinggi': 22 (8.8%)
#   KEHAMILAN                : '-' (236/249 = 94.8%)
#     Top values:              '-': 236 (94.8%)
#                            'Unknown': 13 (5.2%)
#   KEBIASAAN                : 'Unknown' (121/249 = 48.6%)
#     Top values:              'Unknown': 121 (48.6%)
#                            'merokok': 26 (10.4%)
#                            'merokok, lain$  riwayat konsumsi obat kolesterol, insulin$': 1 (0.4%)
#   OLAHRAGA                 : '+' (166/249 = 66.7%)
#     Top values:              '+': 166 (66.7%)
#                            '-': 83 (33.3%)
#   ALERGI                   : '-' (246/249 = 98.8%)
#     Top values:              '-': 246 (98.8%)
#                            '+': 3 (1.2%)
#   TENSI                    : '120/80' (41/249 = 16.5%)
#     Top values:              '120/80': 41 (16.5%)
#                            '130/80': 29 (11.6%)
#                            '110/70': 25 (10.0%)
#   KULIT_RAMBUT             : 'normal' (249/249 = 100.0%)
#   VISUS_MATA               : 'od :  e os :  e' (249/249 = 100.0%)
#   PENYAKIT_MATA            : 'normal' (249/249 = 100.0%)
#   CONJUNGTIVA              : 'normal' (236/249 = 94.8%)
#     Top values:              'normal': 236 (94.8%)
#                            'anemis': 12 (4.8%)
#                            'anemis (minimal)': 1 (0.4%)
#   SCLERA                   : 'normal' (246/249 = 98.8%)
#     Top values:              'normal': 246 (98.8%)
#                            'icteric': 1 (0.4%)
#                            'agak ikhterik': 1 (0.4%)
#   KELAINAN_MATA_LAIN       : 'Unknown' (244/249 = 98.0%)
#     Top values:              'Unknown': 244 (98.0%)
#                            'xanthelasma kelopak mata kiri': 1 (0.4%)
#                            'ptergium mata kanan grade i': 1 (0.4%)
#   TELINGA                  : 'normal' (167/249 = 67.1%)
#     Top values:              'normal': 167 (67.1%)
#                            'tidak periksa': 44 (17.7%)
#                            'tidak diperiksa': 30 (12.0%)
#   MEMBRAN_TYMPANI          : 'normal' (167/249 = 67.1%)
#     Top values:              'normal': 167 (67.1%)
#                            'tidak periksa': 45 (18.1%)
#                            'tidak diperiksa': 30 (12.0%)
#   REFLEK_CAHAYA            : 'normal' (166/249 = 66.7%)
#     Top values:              'normal': 166 (66.7%)
#                            'tidak periksa': 45 (18.1%)
#                            'tidak diperiksa': 30 (12.0%)
#   SERUMEN_PLUG             : 'normal' (145/249 = 58.2%)
#     Top values:              'normal': 145 (58.2%)
#                            'tidak periksa': 45 (18.1%)
#                            'tidak diperiksa': 30 (12.0%)
#   HIDUNG                   : 'normal' (167/249 = 67.1%)
#     Top values:              'normal': 167 (67.1%)
#                            'tidak periksa': 45 (18.1%)
#                            'tidak diperiksa': 30 (12.0%)
#   SEPTUM_DEVIASI           : 'normal' (167/249 = 67.1%)
#     Top values:              'normal': 167 (67.1%)
#                            'tidak periksa': 45 (18.1%)
#                            'tidak diperiksa': 30 (12.0%)
#   CONCHA                   : 'normal' (163/249 = 65.5%)
#     Top values:              'normal': 163 (65.5%)
#                            'tidak periksa': 45 (18.1%)
#                            'tidak diperiksa': 30 (12.0%)
#   POLYP                    : 'normal' (167/249 = 67.1%)
#     Top values:              'normal': 167 (67.1%)
#                            'tidak periksa': 45 (18.1%)
#                            'tidak diperiksa': 30 (12.0%)
#   KERONGKONGAN             : 'normal' (167/249 = 67.1%)
#     Top values:              'normal': 167 (67.1%)
#                            'tidak periksa': 45 (18.1%)
#                            'tidak diperiksa': 30 (12.0%)
#   TONSIL                   : 'normal' (154/249 = 61.8%)
#     Top values:              'normal': 154 (61.8%)
#                            'tidak periksa': 45 (18.1%)
#                            'tidak diperiksa': 30 (12.0%)
#   FARING                   : 'normal' (162/249 = 65.1%)
#     Top values:              'normal': 162 (65.1%)
#                            'tidak periksa': 45 (18.1%)
#                            'tidak diperiksa': 30 (12.0%)
#   AUDIOGRAM                : 'tidak diperiksa' (136/249 = 54.6%)
#     Top values:              'tidak diperiksa': 136 (54.6%)
#                            'tidak periksa': 46 (18.5%)
#                            'normal': 33 (13.3%)
#   HERNIA                   : 'normal' (249/249 = 100.0%)
#   HAEMORROID               : 'normal' (238/249 = 95.6%)
#     Top values:              'normal': 238 (95.6%)
#                            'ada': 11 (4.4%)
#   SPINCER_ANI              : 'normal' (249/249 = 100.0%)
#   EPIDIDYMIS_TESTIS_PROSTAT: 'normal' (204/249 = 81.9%)
#     Top values:              'normal': 204 (81.9%)
#                            'Unknown': 45 (18.1%)
#   VARICOCELE_HYDROCELE     : 'normal' (204/249 = 81.9%)
#     Top values:              'normal': 204 (81.9%)
#                            'Unknown': 45 (18.1%)
#   FLOUR_ALBUS              : 'Unknown' (204/249 = 81.9%)
#     Top values:              'Unknown': 204 (81.9%)
#                            'normal': 44 (17.7%)
#                            'ada': 1 (0.4%)
#   PAPS_SMEAR               : 'Unknown' (215/249 = 86.3%)
#     Top values:              'Unknown': 215 (86.3%)
#                            'normal': 34 (13.7%)
#   LEHER                    : 'normal' (249/249 = 100.0%)
#   JVP                      : 'normal' (248/249 = 99.6%)
#     Top values:              'normal': 248 (99.6%)
#                            'meningkat': 1 (0.4%)
#   STRUMA                   : 'normal' (249/249 = 100.0%)
#   GIGI                     : 'Unknown' (128/249 = 51.4%)
#     Top values:              'Unknown': 128 (51.4%)
#                            '-': 38 (15.3%)
#                            'scalling': 19 (7.6%)
#   MULUT                    : 'tidak diperiksa' (109/249 = 43.8%)
#     Top values:              'tidak diperiksa': 109 (43.8%)
#                            'normal': 68 (27.3%)
#                            'tidak periksa': 61 (24.5%)
#   GUSI                     : 'tidak diperiksa' (109/249 = 43.8%)
#     Top values:              'tidak diperiksa': 109 (43.8%)
#                            'normal': 68 (27.3%)
#                            'tidak periksa': 61 (24.5%)
#   BATAS_JANTUNG            : 'normal' (249/249 = 100.0%)
#   IRAMA_JANTUNG            : 'normal' (249/249 = 100.0%)
#   SUARA_JANTUNG_MURMUR     : 'normal' (249/249 = 100.0%)
#   ECG                      : 'normal' (221/249 = 88.8%)
#     Top values:              'normal': 221 (88.8%)
#                            'sinus takikardia': 3 (1.2%)
#                            'inkomplit rbbb': 3 (1.2%)
#   TREADMILL_TEST           : '(t)-' (99/249 = 39.8%)
#     Top values:              '(t)-': 99 (39.8%)
#                            '(t)': 86 (34.5%)
#                            '(t)tidak melakukan': 15 (6.0%)
#   PERKUSI                  : 'normal' (249/249 = 100.0%)
#   AUSKULTASI               : 'normal' (246/249 = 98.8%)
#     Top values:              'normal': 246 (98.8%)
#                            'wheezing lapang paru kiri': 1 (0.4%)
#                            'vesikular meningkat pada lapang paru kanan': 1 (0.4%)
#   THORAX_PHOTO             : 'normal' (167/249 = 67.1%)
#     Top values:              'normal': 167 (67.1%)
#                            'tidak periksa': 37 (14.9%)
#                            'tidak diperiksa': 28 (11.2%)
#   AUTOSPIROMETRI           : 'tidak diperiksa' (136/249 = 54.6%)
#     Top values:              'tidak diperiksa': 136 (54.6%)
#                            'tidak periksa': 47 (18.9%)
#                            '-': 17 (6.8%)
#   TREMOR                   : 'normal' (247/249 = 99.2%)
#     Top values:              'normal': 247 (99.2%)
#                            'tangan kanan (halus)': 1 (0.4%)
#                            'ada': 1 (0.4%)
#   SEMBAB                   : 'normal' (249/249 = 100.0%)
#   PARALYSE                 : 'normal' (247/249 = 99.2%)
#     Top values:              'normal': 247 (99.2%)
#                            'rigiditas': 1 (0.4%)
#                            'ada': 1 (0.4%)
#   PUPIL                    : 'normal' (249/249 = 100.0%)
#   PATELA                   : 'normal' (248/249 = 99.6%)
#     Top values:              'normal': 248 (99.6%)
#                            'hiperrefleks': 1 (0.4%)
#   ARCHILES                 : 'normal' (249/249 = 100.0%)
#   DINDING_PERUT            : 'normal' (249/249 = 100.0%)
#   PERUT                    : 'normal' (240/249 = 96.4%)
#     Top values:              'normal': 240 (96.4%)
#                            'nyeri tekan': 4 (1.6%)
#                            'nyeri tekan epigastrium': 2 (0.8%)
#   HATI                     : 'normal' (249/249 = 100.0%)
#   LIMPA                    : 'normal' (249/249 = 100.0%)
#   GINJAL_ABDIMEN           : 'normal' (249/249 = 100.0%)
#   USG_ABDOMEN              : 'Unknown' (249/249 = 100.0%)
#   GINJAL_TLG_BELAKANG      : 'normal' (249/249 = 100.0%)
#   PROTEIN_ALBUMIN          : 'negatif' (213/249 = 85.5%)
#     Top values:              'negatif': 213 (85.5%)
#                            'positif 1': 30 (12.0%)
#                            'positif 2': 3 (1.2%)
#   REDUKSI                  : 'negatif' (110/249 = 44.2%)
#     Top values:              'negatif': 110 (44.2%)
#                            'positif 1': 71 (28.5%)
#                            'positif 2': 42 (16.9%)
#   UROBILINOGEN             : 'negatif' (249/249 = 100.0%)
#   BILIRUBIN                : 'negatif' (249/249 = 100.0%)
#   ERITROSIT_RBC            : '0-1' (205/249 = 82.3%)
#     Top values:              '0-1': 205 (82.3%)
#                            '1-2': 24 (9.6%)
#                            '2-3': 7 (2.8%)
#   LEKOSIT_WBC              : '0-1' (106/249 = 42.6%)
#     Top values:              '0-1': 106 (42.6%)
#                            '1-2': 75 (30.1%)
#                            '2-3': 15 (6.0%)
#   SEL_EPITEL               : '0-1' (136/249 = 54.6%)
#     Top values:              '0-1': 136 (54.6%)
#                            '1-2': 50 (20.1%)
#                            '2-3': 12 (4.8%)
#   ASAM_URAT_URIN           : 'negatif' (247/249 = 99.2%)
#     Top values:              'negatif': 247 (99.2%)
#                            'positif': 2 (0.8%)
#   AMORF                    : 'negatif' (248/249 = 99.6%)
#     Top values:              'negatif': 248 (99.6%)
#                            'positif': 1 (0.4%)
#   TRIPLE_PHOSP             : 'negatif' (249/249 = 100.0%)
#   CA_OX                    : 'negatif' (246/249 = 98.8%)
#     Top values:              'negatif': 246 (98.8%)
#                            'positif': 3 (1.2%)
#   GRANULER                 : 'negatif' (243/249 = 97.6%)
#     Top values:              'negatif': 243 (97.6%)
#                            'positif': 6 (2.4%)
#   HYALINE                  : 'negatif' (248/249 = 99.6%)
#     Top values:              'negatif': 248 (99.6%)
#                            'positif': 1 (0.4%)
#   BAKTERI                  : 'negatif' (238/249 = 95.6%)
#     Top values:              'negatif': 238 (95.6%)
#                            'positif': 11 (4.4%)
#   URIN_LAIN2               : 'Unknown' (247/249 = 99.2%)
#     Top values:              'Unknown': 247 (99.2%)
#                            'jamur (+)': 1 (0.4%)
#                            'hyalin (+)': 1 (0.4%)
#   URINE_REDUKSI_PUASA      : 'negatif' (95/249 = 38.2%)
#     Top values:              'negatif': 95 (38.2%)
#                            'positif 1': 88 (35.3%)
#                            'positif 2': 44 (17.7%)
#   URINE_REDUKSI_2JAMPP     : 'positif 2' (88/249 = 35.3%)
#     Top values:              'positif 2': 88 (35.3%)
#                            'positif 1': 86 (34.5%)
#                            'negatif': 30 (12.0%)
#
# 💡 CLUSTER INTERPRETATION: SUHU:4713 | LED:205 | ALKALINE_PHOSPAT:1054
#
#  Cluster Centroid (Normalized Numerical):
# --------------------------------------------------------------------------------
#   [ 4.41557655e-02  2.38550814e-02  5.49262202e-02 -2.24361527e-02
#   1.31241270e-01  1.54289195e-01  2.36090232e-01  2.30698261e-01
#  -9.89070067e-02  1.23813756e-03 -2.34559426e-02  2.80268723e-01
#  -3.52508823e-01 -1.57577749e-01  7.04295814e-03 -2.18170863e-01
#   5.07509346e-04  4.78119710e-02  5.49670260e-02  4.77610988e-03
#   1.11009984e+00  6.40112545e-01  5.10638855e-01  1.33735592e+00
#   7.73324627e-01  8.25384513e-01 -3.14603753e-01  6.36743963e-01
#   2.98543208e-01  3.43790080e-02 -3.11344336e-01  5.15922957e+00
#   5.13318497e+00]
#
#  Cluster Centroid (Categorical):
#   ['Unknown' '-' 'Unknown' '+' '-' '120/80' 'normal' 'od :  e os :  e'
#  'normal' 'normal' 'normal' 'Unknown' 'normal' 'normal' 'normal' 'normal'
#  'normal' 'normal' 'normal' 'normal' 'normal' 'normal' 'normal'
#  'tidak diperiksa' 'normal' 'normal' 'normal' 'normal' 'normal' 'Unknown'
#  'Unknown' 'normal' 'normal' 'normal' 'Unknown' 'tidak diperiksa'
#  'tidak diperiksa' 'normal' 'normal' 'normal' 'normal' '(t)-' 'normal'
#  'normal' 'normal' 'tidak diperiksa' 'normal' 'normal' 'normal' 'normal'
#  'normal' 'normal' 'normal' 'normal' 'normal' 'normal' 'normal' 'Unknown'
# ...
#   • PERUT: Predominantly 'normal' (100.0%)
#   • HATI: Predominantly 'normal' (100.0%)
#   • LIMPA: Predominantly 'normal' (100.0%)
#   • GINJAL_ABDIMEN: Predominantly 'normal' (100.0%)
#   • USG_ABDOMEN: Predominantly 'Unknown' (100.0%)
#   • GINJAL_TLG_BELAKANG: Predominantly 'normal' (100.0%)
#   • PROTEIN_ALBUMIN: Predominantly 'negatif' (100.0%)
#   • REDUKSI: Predominantly 'negatif' (100.0%)
#   • UROBILINOGEN: Predominantly 'negatif' (100.0%)
#   • BILIRUBIN: Predominantly 'negatif' (100.0%)
#   • ERITROSIT_RBC: Predominantly '0-1' (77.8%)
#   • SEL_EPITEL: Predominantly '0-1' (66.7%)
#   • ASAM_URAT_URIN: Predominantly 'negatif' (100.0%)
#   • AMORF: Predominantly 'negatif' (100.0%)
#   • TRIPLE_PHOSP: Predominantly 'negatif' (100.0%)
#   • CA_OX: Predominantly 'negatif' (100.0%)
#   • GRANULER: Predominantly 'negatif' (100.0%)
#   • HYALINE: Predominantly 'negatif' (100.0%)
#   • BAKTERI: Predominantly 'negatif' (100.0%)
#   • URIN_LAIN2: Predominantly 'Unknown' (100.0%)
#   • URINE_REDUKSI_PUASA: Predominantly 'negatif' (100.0%)
#   • URINE_REDUKSI_2JAMPP: Predominantly 'negatif' (88.9%)
#
#  Business Interpretation:
#   PENYAKIT_KELUARGA='Unknown' | KEHAMILAN='-' | KEBIASAAN='Unknown' | OLAHRAGA='-'
#
#  Key Insights:
#   • Health Metrics Present: NADI, SUHU, BERAT
#
# ================================================================================
# CLUSTER 2: SUHU:4713 | LED:205 | ALKALINE_PHOSPAT:1054
# ================================================================================
# Size: 249 members (2.3% of total)
#
# 🔢 Numerical Characteristics:
#   • GULA_DARAH_PUASA: significantly higher (2158.47 vs 943.02)
#   • GULA_DARAH_2JAMPP: significantly higher (2760.76 vs 1003.05)
#
# 🏷️  Categorical Characteristics:
#   • KEHAMILAN: Predominantly '-' (94.8%)
#   • OLAHRAGA: Predominantly '+' (66.7%)
#   • ALERGI: Predominantly '-' (98.8%)
#   • KULIT_RAMBUT: Predominantly 'normal' (100.0%)
#   • VISUS_MATA: Predominantly 'od :  e os :  e' (100.0%)
#   • PENYAKIT_MATA: Predominantly 'normal' (100.0%)
#   • CONJUNGTIVA: Predominantly 'normal' (94.8%)
#   • SCLERA: Predominantly 'normal' (98.8%)
#   • KELAINAN_MATA_LAIN: Predominantly 'Unknown' (98.0%)
#   • TELINGA: Predominantly 'normal' (67.1%)
#   • MEMBRAN_TYMPANI: Predominantly 'normal' (67.1%)
#   • REFLEK_CAHAYA: Predominantly 'normal' (66.7%)
#   • HIDUNG: Predominantly 'normal' (67.1%)
#   • SEPTUM_DEVIASI: Predominantly 'normal' (67.1%)
#   • CONCHA: Predominantly 'normal' (65.5%)
#   • POLYP: Predominantly 'normal' (67.1%)
#   • KERONGKONGAN: Predominantly 'normal' (67.1%)
#   • TONSIL: Predominantly 'normal' (61.8%)
#   • FARING: Predominantly 'normal' (65.1%)
#   • HERNIA: Predominantly 'normal' (100.0%)
#   • HAEMORROID: Predominantly 'normal' (95.6%)
#   • SPINCER_ANI: Predominantly 'normal' (100.0%)
#   • EPIDIDYMIS_TESTIS_PROSTAT: Predominantly 'normal' (81.9%)
#   • VARICOCELE_HYDROCELE: Predominantly 'normal' (81.9%)
#   • FLOUR_ALBUS: Predominantly 'Unknown' (81.9%)
#   • PAPS_SMEAR: Predominantly 'Unknown' (86.3%)
#   • LEHER: Predominantly 'normal' (100.0%)
#   • JVP: Predominantly 'normal' (99.6%)
#   • STRUMA: Predominantly 'normal' (100.0%)
#   • BATAS_JANTUNG: Predominantly 'normal' (100.0%)
#   • IRAMA_JANTUNG: Predominantly 'normal' (100.0%)
#   • SUARA_JANTUNG_MURMUR: Predominantly 'normal' (100.0%)
#   • ECG: Predominantly 'normal' (88.8%)
#   • PERKUSI: Predominantly 'normal' (100.0%)
#   • AUSKULTASI: Predominantly 'normal' (98.8%)
#   • THORAX_PHOTO: Predominantly 'normal' (67.1%)
#   • TREMOR: Predominantly 'normal' (99.2%)
#   • SEMBAB: Predominantly 'normal' (100.0%)
#   • PARALYSE: Predominantly 'normal' (99.2%)
#   • PUPIL: Predominantly 'normal' (100.0%)
#   • PATELA: Predominantly 'normal' (99.6%)
#   • ARCHILES: Predominantly 'normal' (100.0%)
#   • DINDING_PERUT: Predominantly 'normal' (100.0%)
#   • PERUT: Predominantly 'normal' (96.4%)
#   • HATI: Predominantly 'normal' (100.0%)
#   • LIMPA: Predominantly 'normal' (100.0%)
#   • GINJAL_ABDIMEN: Predominantly 'normal' (100.0%)
#   • USG_ABDOMEN: Predominantly 'Unknown' (100.0%)
#   • GINJAL_TLG_BELAKANG: Predominantly 'normal' (100.0%)
#   • PROTEIN_ALBUMIN: Predominantly 'negatif' (85.5%)
#   • UROBILINOGEN: Predominantly 'negatif' (100.0%)
#   • BILIRUBIN: Predominantly 'negatif' (100.0%)
#   • ERITROSIT_RBC: Predominantly '0-1' (82.3%)
#   • ASAM_URAT_URIN: Predominantly 'negatif' (99.2%)
#   • AMORF: Predominantly 'negatif' (99.6%)
#   • TRIPLE_PHOSP: Predominantly 'negatif' (100.0%)
#   • CA_OX: Predominantly 'negatif' (98.8%)
#   • GRANULER: Predominantly 'negatif' (97.6%)
#   • HYALINE: Predominantly 'negatif' (99.6%)
#   • BAKTERI: Predominantly 'negatif' (95.6%)
#   • URIN_LAIN2: Predominantly 'Unknown' (99.2%)
#
#  Business Interpretation:
#   PENYAKIT_KELUARGA='Unknown' | KEHAMILAN='-' | KEBIASAAN='Unknown' | OLAHRAGA='+'
#
#  Key Insights:
#   • Health Metrics Present: NADI, SUHU, BERAT
#
# ================================================================================
# CLUSTER 3: LED:299 | BILIRUBIN_TOTAL:440 | BILIRUBIN_INDIRECT:265
# ================================================================================
# Size: 2774 members (26.1% of total)
#
# 🏷️  Categorical Characteristics:
#   • KEHAMILAN: Predominantly '-' (78.5%)
#   • KEBIASAAN: Predominantly 'Unknown' (66.0%)
#   • OLAHRAGA: Predominantly '+' (67.9%)
#   • ALERGI: Predominantly '-' (95.8%)
#   • KULIT_RAMBUT: Predominantly 'normal' (100.0%)
#   • VISUS_MATA: Predominantly 'od :  e os :  e' (100.0%)
#   • PENYAKIT_MATA: Predominantly 'normal' (100.0%)
#   • CONJUNGTIVA: Predominantly 'normal' (92.8%)
#   • SCLERA: Predominantly 'normal' (100.0%)
#   • KELAINAN_MATA_LAIN: Predominantly 'Unknown' (99.4%)
#   • TELINGA: Predominantly 'normal' (67.2%)
#   • MEMBRAN_TYMPANI: Predominantly 'normal' (67.1%)
#   • REFLEK_CAHAYA: Predominantly 'normal' (67.2%)
#   • SERUMEN_PLUG: Predominantly 'normal' (62.9%)
#   • HIDUNG: Predominantly 'normal' (67.3%)
#   • SEPTUM_DEVIASI: Predominantly 'normal' (67.3%)
#   • CONCHA: Predominantly 'normal' (64.9%)
#   • POLYP: Predominantly 'normal' (67.3%)
#   • KERONGKONGAN: Predominantly 'normal' (67.2%)
#   • TONSIL: Predominantly 'normal' (63.6%)
#   • FARING: Predominantly 'normal' (65.9%)
#   • AUDIOGRAM: Predominantly 'tidak diperiksa' (67.9%)
#   • HERNIA: Predominantly 'normal' (100.0%)
#   • HAEMORROID: Predominantly 'normal' (91.6%)
#   • SPINCER_ANI: Predominantly 'normal' (100.0%)
#   • EPIDIDYMIS_TESTIS_PROSTAT: Predominantly 'Unknown' (82.8%)
#   • VARICOCELE_HYDROCELE: Predominantly 'Unknown' (82.8%)
#   • FLOUR_ALBUS: Predominantly 'normal' (81.7%)
#   • PAPS_SMEAR: Predominantly 'normal' (69.6%)
#   • LEHER: Predominantly 'normal' (99.6%)
#   • JVP: Predominantly 'normal' (100.0%)
#   • STRUMA: Predominantly 'normal' (99.9%)
#   • BATAS_JANTUNG: Predominantly 'normal' (100.0%)
#   • IRAMA_JANTUNG: Predominantly 'normal' (99.8%)
#   • SUARA_JANTUNG_MURMUR: Predominantly 'normal' (100.0%)
#   • ECG: Predominantly 'normal' (93.7%)
#   • TREADMILL_TEST: Predominantly '(t)-' (85.9%)
#   • PERKUSI: Predominantly 'normal' (100.0%)
#   • AUSKULTASI: Predominantly 'normal' (99.9%)
#   • THORAX_PHOTO: Predominantly 'normal' (62.5%)
#   • AUTOSPIROMETRI: Predominantly 'tidak diperiksa' (67.9%)
#   • TREMOR: Predominantly 'normal' (99.4%)
#   • SEMBAB: Predominantly 'normal' (100.0%)
#   • PARALYSE: Predominantly 'normal' (100.0%)
#   • PUPIL: Predominantly 'normal' (100.0%)
#   • PATELA: Predominantly 'normal' (100.0%)
#   • ARCHILES: Predominantly 'normal' (100.0%)
#   • DINDING_PERUT: Predominantly 'normal' (99.9%)
#   • PERUT: Predominantly 'normal' (95.8%)
#   • HATI: Predominantly 'normal' (100.0%)
#   • LIMPA: Predominantly 'normal' (100.0%)
#   • GINJAL_ABDIMEN: Predominantly 'normal' (100.0%)
#   • USG_ABDOMEN: Predominantly 'Unknown' (99.9%)
#   • GINJAL_TLG_BELAKANG: Predominantly 'normal' (100.0%)
#   • PROTEIN_ALBUMIN: Predominantly 'negatif' (99.3%)
#   • REDUKSI: Predominantly 'negatif' (99.9%)
#   • UROBILINOGEN: Predominantly 'negatif' (99.9%)
#   • BILIRUBIN: Predominantly 'negatif' (99.9%)
#   • ERITROSIT_RBC: Predominantly '0-1' (69.9%)
#   • ASAM_URAT_URIN: Predominantly 'negatif' (99.9%)
#   • AMORF: Predominantly 'negatif' (99.5%)
#   • TRIPLE_PHOSP: Predominantly 'negatif' (99.9%)
#   • CA_OX: Predominantly 'negatif' (99.5%)
#   • GRANULER: Predominantly 'negatif' (99.7%)
#   • HYALINE: Predominantly 'negatif' (99.9%)
#   • BAKTERI: Predominantly 'negatif' (88.6%)
#   • URIN_LAIN2: Predominantly 'Unknown' (99.3%)
#   • URINE_REDUKSI_PUASA: Predominantly 'negatif' (99.9%)
#   • URINE_REDUKSI_2JAMPP: Predominantly 'negatif' (99.1%)
#
#  Business Interpretation:
#   PENYAKIT_KELUARGA='Unknown' | KEHAMILAN='-' | KEBIASAAN='Unknown' | OLAHRAGA='+'
#
#  Key Insights:
#   • Health Metrics Present: NADI, SUHU, BERAT
#
# ================================================================================
# CLUSTER 4: HB:317 | STAF:17 | KEHAMILAN=-
# ================================================================================
# Size: 868 members (8.2% of total)
#
# 🔢 Numerical Characteristics:
#   • HB: significantly lower (317.42 vs 12847.87)
#
# 🏷️  Categorical Characteristics:
#   • KEHAMILAN: Predominantly '-' (94.7%)
#   • KEBIASAAN: Predominantly 'Unknown' (62.0%)
#   • OLAHRAGA: Predominantly '+' (66.1%)
#   • ALERGI: Predominantly '-' (96.8%)
#   • KULIT_RAMBUT: Predominantly 'normal' (100.0%)
#   • VISUS_MATA: Predominantly 'od :  e os :  e' (100.0%)
#   • PENYAKIT_MATA: Predominantly 'normal' (100.0%)
#   • CONJUNGTIVA: Predominantly 'normal' (98.0%)
#   • SCLERA: Predominantly 'normal' (100.0%)
#   • KELAINAN_MATA_LAIN: Predominantly 'Unknown' (99.4%)
#   • TELINGA: Predominantly 'normal' (62.4%)
#   • MEMBRAN_TYMPANI: Predominantly 'normal' (62.6%)
#   • REFLEK_CAHAYA: Predominantly 'normal' (62.6%)
#   • HIDUNG: Predominantly 'normal' (62.6%)
#   • SEPTUM_DEVIASI: Predominantly 'normal' (62.3%)
#   • POLYP: Predominantly 'normal' (62.6%)
#   • KERONGKONGAN: Predominantly 'normal' (62.6%)
#   • FARING: Predominantly 'normal' (61.1%)
#   • HERNIA: Predominantly 'normal' (99.9%)
#   • HAEMORROID: Predominantly 'normal' (96.4%)
#   • SPINCER_ANI: Predominantly 'normal' (100.0%)
#   • EPIDIDYMIS_TESTIS_PROSTAT: Predominantly 'normal' (79.6%)
#   • VARICOCELE_HYDROCELE: Predominantly 'normal' (79.6%)
#   • FLOUR_ALBUS: Predominantly 'Unknown' (79.6%)
#   • PAPS_SMEAR: Predominantly 'Unknown' (82.7%)
#   • LEHER: Predominantly 'normal' (99.7%)
#   • JVP: Predominantly 'normal' (100.0%)
#   • STRUMA: Predominantly 'normal' (100.0%)
#   • BATAS_JANTUNG: Predominantly 'normal' (100.0%)
#   • IRAMA_JANTUNG: Predominantly 'normal' (100.0%)
#   • SUARA_JANTUNG_MURMUR: Predominantly 'normal' (100.0%)
#   • ECG: Predominantly 'normal' (94.2%)
#   • TREADMILL_TEST: Predominantly '(t)-' (79.6%)
#   • PERKUSI: Predominantly 'normal' (100.0%)
#   • AUSKULTASI: Predominantly 'normal' (100.0%)
#   • THORAX_PHOTO: Predominantly 'normal' (63.2%)
#   • TREMOR: Predominantly 'normal' (99.7%)
#   • SEMBAB: Predominantly 'normal' (100.0%)
#   • PARALYSE: Predominantly 'normal' (99.9%)
#   • PUPIL: Predominantly 'normal' (100.0%)
#   • PATELA: Predominantly 'normal' (99.9%)
#   • ARCHILES: Predominantly 'normal' (100.0%)
#   • DINDING_PERUT: Predominantly 'normal' (100.0%)
#   • PERUT: Predominantly 'normal' (98.5%)
#   • HATI: Predominantly 'normal' (100.0%)
#   • LIMPA: Predominantly 'normal' (100.0%)
#   • GINJAL_ABDIMEN: Predominantly 'normal' (100.0%)
#   • USG_ABDOMEN: Predominantly 'Unknown' (99.9%)
#   • GINJAL_TLG_BELAKANG: Predominantly 'normal' (100.0%)
#   • PROTEIN_ALBUMIN: Predominantly 'negatif' (99.7%)
#   • REDUKSI: Predominantly 'negatif' (100.0%)
#   • UROBILINOGEN: Predominantly 'negatif' (100.0%)
#   • BILIRUBIN: Predominantly 'negatif' (100.0%)
#   • ERITROSIT_RBC: Predominantly '0-1' (85.6%)
#   • SEL_EPITEL: Predominantly '0-1' (60.3%)
#   • ASAM_URAT_URIN: Predominantly 'negatif' (99.9%)
#   • AMORF: Predominantly 'negatif' (99.7%)
#   • TRIPLE_PHOSP: Predominantly 'negatif' (100.0%)
#   • CA_OX: Predominantly 'negatif' (99.2%)
#   • GRANULER: Predominantly 'negatif' (99.8%)
#   • HYALINE: Predominantly 'negatif' (99.9%)
#   • BAKTERI: Predominantly 'negatif' (97.1%)
#   • URIN_LAIN2: Predominantly 'Unknown' (100.0%)
#   • URINE_REDUKSI_PUASA: Predominantly 'negatif' (99.9%)
#   • URINE_REDUKSI_2JAMPP: Predominantly 'negatif' (99.2%)
#
#  Business Interpretation:
#   PENYAKIT_KELUARGA='Unknown' | KEHAMILAN='-' | KEBIASAAN='Unknown' | OLAHRAGA='+'
#
#  Key Insights:
#   • Health Metrics Present: NADI, SUHU, BERAT
#
# ================================================================================
# CLUSTER 5: LED:130 | SGPT:381 | GAMMA_GT:482
# ================================================================================
# Size: 4514 members (42.4% of total)
#
# 🏷️  Categorical Characteristics:
#   • KEHAMILAN: Predominantly '-' (98.9%)
#   • OLAHRAGA: Predominantly '+' (66.9%)
#   • ALERGI: Predominantly '-' (97.7%)
#   • KULIT_RAMBUT: Predominantly 'normal' (100.0%)
#   • VISUS_MATA: Predominantly 'od :  e os :  e' (100.0%)
#   • PENYAKIT_MATA: Predominantly 'normal' (99.9%)
#   • CONJUNGTIVA: Predominantly 'normal' (98.3%)
#   • SCLERA: Predominantly 'normal' (100.0%)
#   • KELAINAN_MATA_LAIN: Predominantly 'Unknown' (99.2%)
#   • TELINGA: Predominantly 'normal' (61.8%)
#   • MEMBRAN_TYMPANI: Predominantly 'normal' (61.8%)
#   • REFLEK_CAHAYA: Predominantly 'normal' (61.8%)
#   • HIDUNG: Predominantly 'normal' (61.9%)
#   • SEPTUM_DEVIASI: Predominantly 'normal' (61.7%)
#   • CONCHA: Predominantly 'normal' (60.5%)
#   • POLYP: Predominantly 'normal' (61.9%)
#   • KERONGKONGAN: Predominantly 'normal' (61.9%)
#   • FARING: Predominantly 'normal' (60.1%)
#   • HERNIA: Predominantly 'normal' (100.0%)
#   • HAEMORROID: Predominantly 'normal' (96.5%)
#   • SPINCER_ANI: Predominantly 'normal' (100.0%)
#   • EPIDIDYMIS_TESTIS_PROSTAT: Predominantly 'normal' (96.8%)
#   • VARICOCELE_HYDROCELE: Predominantly 'normal' (96.8%)
#   • FLOUR_ALBUS: Predominantly 'Unknown' (96.5%)
#   • PAPS_SMEAR: Predominantly 'Unknown' (97.1%)
#   • LEHER: Predominantly 'normal' (99.9%)
#   • JVP: Predominantly 'normal' (100.0%)
#   • STRUMA: Predominantly 'normal' (100.0%)
#   • BATAS_JANTUNG: Predominantly 'normal' (100.0%)
#   • IRAMA_JANTUNG: Predominantly 'normal' (99.8%)
#   • SUARA_JANTUNG_MURMUR: Predominantly 'normal' (99.9%)
#   • ECG: Predominantly 'normal' (94.1%)
#   • TREADMILL_TEST: Predominantly '(t)-' (75.6%)
#   • PERKUSI: Predominantly 'normal' (100.0%)
#   • AUSKULTASI: Predominantly 'normal' (99.9%)
#   • THORAX_PHOTO: Predominantly 'normal' (63.9%)
#   • TREMOR: Predominantly 'normal' (99.6%)
#   • SEMBAB: Predominantly 'normal' (99.9%)
#   • PARALYSE: Predominantly 'normal' (100.0%)
#   • PUPIL: Predominantly 'normal' (100.0%)
#   • PATELA: Predominantly 'normal' (100.0%)
#   • ARCHILES: Predominantly 'normal' (100.0%)
#   • DINDING_PERUT: Predominantly 'normal' (100.0%)
#   • PERUT: Predominantly 'normal' (98.6%)
#   • HATI: Predominantly 'normal' (100.0%)
#   • LIMPA: Predominantly 'normal' (100.0%)
#   • GINJAL_ABDIMEN: Predominantly 'normal' (100.0%)
#   • USG_ABDOMEN: Predominantly 'Unknown' (100.0%)
#   • GINJAL_TLG_BELAKANG: Predominantly 'normal' (100.0%)
#   • PROTEIN_ALBUMIN: Predominantly 'negatif' (99.2%)
#   • REDUKSI: Predominantly 'negatif' (99.8%)
#   • UROBILINOGEN: Predominantly 'negatif' (100.0%)
#   • BILIRUBIN: Predominantly 'negatif' (100.0%)
#   • ERITROSIT_RBC: Predominantly '0-1' (89.7%)
#   • LEKOSIT_WBC: Predominantly '0-1' (67.6%)
#   • SEL_EPITEL: Predominantly '0-1' (69.6%)
#   • ASAM_URAT_URIN: Predominantly 'negatif' (100.0%)
#   • AMORF: Predominantly 'negatif' (99.6%)
#   • TRIPLE_PHOSP: Predominantly 'negatif' (100.0%)
#   • CA_OX: Predominantly 'negatif' (99.5%)
#   • GRANULER: Predominantly 'negatif' (99.8%)
#   • HYALINE: Predominantly 'negatif' (99.8%)
#   • BAKTERI: Predominantly 'negatif' (99.4%)
#   • URIN_LAIN2: Predominantly 'Unknown' (99.9%)
#   • URINE_REDUKSI_PUASA: Predominantly 'negatif' (99.8%)
#   • URINE_REDUKSI_2JAMPP: Predominantly 'negatif' (98.8%)
#
#  Business Interpretation:
#   PENYAKIT_KELUARGA='Unknown' | KEHAMILAN='-' | KEBIASAAN='Unknown' | OLAHRAGA='+'
#
#  Key Insights:
#   • Health Metrics Present: NADI, SUHU, BERAT
#
# ================================================================================
# ANALYSIS COMPLETE
# ================================================================================
#
# Total Clusters: 6
# Optimization Parameters: k=6, gamma=0.100
# Final Cost: 304629.08
